# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,1,2,3,4,5,6],header = None)
enrichment.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
greedy = pd.read_csv("greedy_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
greedy.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
RILP = pd.read_csv("RILP_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
RILP.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,1,2,3,4,5,6],header = None)
Tabu_PNPSC.columns = ["Groups","Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"]
enrichment_new = pd.melt(enrichment, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
enrichment_new['method'] = "Enrch"
greedy_new = pd.melt(greedy, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
greedy_new['method'] = "Grdy"
RILP_new = pd.melt(RILP, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
RILP_new['method'] = "RILP"
Tabu_PNPSC_new = pd.melt(Tabu_PNPSC, value_vars=["Sensitivity","Specificity","Accuracy","Precision","F1_score","Num_motifs"],id_vars='Groups')
Tabu_PNPSC_new['method'] = "TABU"
frames = [enrichment_new, greedy_new,RILP_new,Tabu_PNPSC_new]
result = pd.concat(frames)

# %%
enrichment_new
# Out:
#       Groups     variable      value method
# 0        E2F  Sensitivity   0.865200  Enrch
# 1       HNF4  Sensitivity   0.766800  Enrch
# 2        MYC  Sensitivity   0.793800  Enrch
# 3       GATA  Sensitivity   0.642900  Enrch
# 4      TFAP2  Sensitivity   0.838800  Enrch
# 5        IRF  Sensitivity   0.824300  Enrch
# 6        ETS  Sensitivity   0.899100  Enrch
# 7      NR3C1  Sensitivity   0.747100  Enrch
# 8       STAT  Sensitivity   0.786100  Enrch
# 9       ATF3  Sensitivity   0.712309  Enrch
# 10    POU2F2  Sensitivity   0.580600  Enrch
# 11      RXRA  Sensitivity   0.594400  Enrch
# 12      EGR1  Sensitivity   0.898400  Enrch
# 13      MEF2  Sensitivity   0.502000  Enrch
# 14       MAF  Sensitivity   0.599800  Enrch
# 15     ESRRA  Sensitivity   0.666500  Enrch
# 16      NFKB  Sensitivity   0.706000  Enrch
# 17       AP1  Sensitivity   0.865100  Enrch
# 18     CEBPB  Sensitivity   0.316800  Enrch
# 19       SRF  Sensitivity   0.521400  Enrch
# 20      RFX5  Sensitivity   0.423300  Enrch
# 21       SP1  Sensitivity   0.630700  Enrch
# 22      FOXA  Sensitivity   0.600800  Enrch
# 23       YY1  Sensitivity   0.796300  Enrch
# 24      SIX5  Sensitivity   0.547041  Enrch
# 25    TCF7L2  Sensitivity   0.445000  Enrch
# 26      TATA  Sensitivity   0.863800  Enrch
# 27       NFY  Sensitivity   0.842700  Enrch
# 28     SREBP  Sensitivity   0.264843  Enrch
# 29      PAX5  Sensitivity   0.718100  Enrch
# ..       ...          ...        ...    ...
# 300   TCF7L2   Num_motifs   2.000000  Enrch
# 301     TATA   Num_motifs  10.000000  Enrch
# 302      NFY   Num_motifs   1.000000  Enrch
# 303    SREBP   Num_motifs   1.000000  Enrch
# 304     PAX5   Num_motifs   5.000000  Enrch
# 305   POU5F1   Num_motifs   2.000000  Enrch
# 306     TAL1   Num_motifs   2.000000  Enrch
# 307      HSF   Num_motifs   1.000000  Enrch
# 308     ZEB1   Num_motifs   1.000000  Enrch
# 309     REST   Num_motifs  10.000000  Enrch
# 310     SPI1   Num_motifs   3.000000  Enrch
# 311  BHLHE40   Num_motifs   2.000000  Enrch
# 312     EBF1   Num_motifs   2.000000  Enrch
# 313   ZBTB7A   Num_motifs   2.000000  Enrch
# 314     ELF1   Num_motifs   3.000000  Enrch
# 315     CTCF   Num_motifs  10.000000  Enrch
# 316     NFE2   Num_motifs   4.000000  Enrch
# 317   ZNF143   Num_motifs   4.000000  Enrch
# 318     NRF1   Num_motifs   3.000000  Enrch
# 319    PRDM1   Num_motifs   2.000000  Enrch
# 320    BRCA1   Num_motifs   1.000000  Enrch
# 321    EP300   Num_motifs  10.000000  Enrch
# 322    TCF12   Num_motifs   6.000000  Enrch
# 323    NANOG   Num_motifs   4.000000  Enrch
# 324   ZBTB33   Num_motifs   4.000000  Enrch
# 325     BATF   Num_motifs   3.000000  Enrch
# 326    NR2C2   Num_motifs   3.000000  Enrch
# 327     PBX3   Num_motifs   3.000000  Enrch
# 328     HEY1   Num_motifs   2.000000  Enrch
# 329     MXI1   Num_motifs   2.000000  Enrch
#
# [330 rows x 4 columns]

# %%
data = result[result['variable'] == "Sensitivity"]
data['value'] = data['value']*100
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
result.shape
# Out:
# (1296, 4)

# %%
6*55*4
# Out:
# 1320

# %%
result = result.sort_values("value",ascending=False)

# %%
f, ax = plt.subplots(figsize=(25,15))
cust_pal = {
"Enrch" : "#6600ff",
"Grdy" : "#66ff66",
"RILP" : "#ff0000",
"TABU" : "#66ffff"
}
temp = result
temp['value'] = temp['value']*100
g = sns.pointplot(x="Groups",alpha=0.7,size=15,y="value",hue='method',data=temp[temp['variable']=="Sensitivity"],palette=cust_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=60)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=15)
ax.set_xlabel('')
ax.set_ylabel('Foreground Coverage%',fontsize=30)
ax.set_ylim([10, 100])
legend = plt.legend(loc=3, prop={'size': 20},frameon = 1)
#frame = legend.get_frame()
#frame.set_facecolor('white')
#frame.set_edgecolor('white')
# path = "/home/osboxes/visualization/3algs/AccuracyOnThree_ALPH.png"
plt.savefig("Sensitivity-line.png",dpi=300)

# %%
f, ax = plt.subplots(figsize=(25,15))
cust_pal = {
"Enrch" : "#6600ff",
"Grdy" : "#66ff66",
"RILP" : "#ff0000",
"TABU" : "#66ffff"
}
temp = result.copy()
temp['value'] = 100 - temp['value']*100
g = sns.pointplot(x="Groups",alpha=0.7,size=15,y="value",hue='method',data=temp[temp['variable']=="Specificity"],palette=cust_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=60)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=15)
ax.set_xlabel('')
ax.set_ylabel('Background Coverage%',fontsize=30)
ax.set_ylim([0, 60])
legend = plt.legend(loc=4, prop={'size': 20},frameon = 1)
#frame = legend.get_frame()
#frame.set_facecolor('white')
#frame.set_edgecolor('white')
# path = "/home/osboxes/visualization/3algs/AccuracyOnThree_ALPH.png"
plt.savefig("Specificity-line.png",dpi=300)

# %%
f, ax = plt.subplots(figsize=(25,15))
cust_pal = {
"Enrch" : "#6600ff",
"Grdy" : "#66ff66",
"RILP" : "#ff0000",
"TABU" : "#66ffff"
}
temp = result.copy()
temp['value'] = 100 - temp['value']*100
g = sns.pointplot(x="Groups",alpha=0.7,size=15,y="value",hue='method',data=temp[temp['variable']=="Accuracy"],palette=cust_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=60)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=15)
ax.set_xlabel('')
ax.set_ylabel('Error rate%',fontsize=30)
ax.set_ylim([0, 60])
legend = plt.legend(loc=4, prop={'size': 20},frameon = 1)
#frame = legend.get_frame()
#frame.set_facecolor('white')
#frame.set_edgecolor('white')
# path = "/home/osboxes/visualization/3algs/AccuracyOnThree_ALPH.png"
plt.savefig("Accuracy-line.png",dpi=300)

# %%
f, ax = plt.subplots(figsize=(25,15))
cust_pal = {
"Enrch" : "#6600ff",
"Grdy" : "#66ff66",
"RILP" : "#ff0000",
"TABU" : "#66ffff"
}
temp = result.copy()
# temp['value'] = 100 - temp['value']*100
g = sns.pointplot(x="Groups",alpha=0.7,size=15,y="value",hue='method',data=temp[temp['variable']=="Num_motifs"],palette=cust_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=60)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=15)
ax.set_xlabel('')
ax.set_ylabel('Numer of motifs',fontsize=30)
ax.set_ylim([0, 12])
legend = plt.legend(loc=1, prop={'size': 20},frameon = 1)
#frame = legend.get_frame()
#frame.set_facecolor('white')
#frame.set_edgecolor('white')
# path = "/home/osboxes/visualization/3algs/AccuracyOnThree_ALPH.png"
plt.savefig("Num_motifs-line.png",dpi=300)

# %%
# sns.set_style("whitegrid")

f, ax = plt.subplots(figsize=(5, 5))
# tips = sns.load_dataset("tips")
data = result[result['variable'] == "Sensitivity"]
data['value'] = data['value']*100
sns.boxplot(x="method", y="value", data=data,boxprops=dict(alpha=.2))
sns.swarmplot(x="method", y="value", data=data,split =True,alpha=.4)
import numpy as np
medians = data.groupby(['method'])['value'].median().values
median_labels = [str(np.round(s, 1)) for s in medians]

pos = range(len(medians))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.5, median_labels[tick], 
            horizontalalignment='center', size=15, color='black', weight='semibold')
ax.set_ylabel('Foreground Coverage%')
ax.set_xlabel('')
ax.set_ylim([10, 100])
plt.savefig("foreCov.png",dpi=600)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# sns.set_style("whitegrid")

f, ax = plt.subplots(figsize=(5, 5))
# tips = sns.load_dataset("tips")
data = result[result['variable'] == "Specificity"]
data['value'] = 1-data['value']
data['value'] = data['value']*100
sns.boxplot(x="method", y="value", data=data,boxprops=dict(alpha=.2))
sns.swarmplot(x="method", y="value", data=data,split =True,alpha=.4)
import numpy as np
medians = data.groupby(['method'])['value'].median().values
median_labels = [str(np.round(s, 1)) for s in medians]

pos = range(len(medians))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.5, median_labels[tick], 
            horizontalalignment='center', size=15, color='black', weight='semibold')
ax.set_ylabel('Background Coverage%')
ax.set_xlabel('')
ax.set_ylim([0, 60])
plt.savefig("backCov.png",dpi=600)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# sns.set_style("whitegrid")

f, ax = plt.subplots(figsize=(5, 5))
# tips = sns.load_dataset("tips")
data = result[result['variable'] == "Accuracy"]
data['value'] = 1-data['value']
data['value'] = data['value']*100
sns.boxplot(x="method", y="value", data=data,boxprops=dict(alpha=.2))
sns.swarmplot(x="method", y="value", data=data,split =True,alpha=.4)
import numpy as np
medians = data.groupby(['method'])['value'].median().values
median_labels = [str(np.round(s, 1)) for s in medians]

pos = range(len(medians))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.5, median_labels[tick], 
            horizontalalignment='center', size=15, color='black', weight='semibold')
ax.set_ylabel('Error rate%')
ax.set_xlabel('')
ax.set_ylim([0, 45])
plt.savefig("error_rate.png",dpi=600)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.py:2783: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
# sns.set_style("whitegrid")

f, ax = plt.subplots(figsize=(5, 5))
# tips = sns.load_dataset("tips")
data = result[result['variable'] == "Num_motifs"]
# data['value'] = 1-data['value']
# data['value'] = data['value']*100
sns.boxplot(x="method", y="value", data=data,boxprops=dict(alpha=.2))
sns.swarmplot(x="method", y="value", data=data,split =True,alpha=.4)
import numpy as np
medians = data.groupby(['method'])['value'].median().values
median_labels = [str(np.round(s, 0)) for s in medians]

pos = range(len(medians))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.2, median_labels[tick], 
            horizontalalignment='center', size=15, color='black', weight='semibold')
ax.set_ylabel('Number of motifs')
ax.set_xlabel('')
ax.set_ylim([0, 13])
plt.savefig("num_motif.png",dpi=600)
