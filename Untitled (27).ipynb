# %%
import pandas as pd

# %%
data = pd.read_csv("./HRGP_dataset/HRGP_raw_both_strand.csv",index_col=0)
data
# Out:
#                                                     gimme_15_BioProspector_w10_5  \
# AT3G57690|AT3G57690.1|AGP23|3|21384146|21384605                              1.0
# AT2G18470|AT2G18470.3;AT2G18470.1;AT2G18470.2;A...                           0.0
# AT4G33970|AT4G33970.1|PEX4|4|16278941|16282048                               1.0
# AT3G18810|AT3G18810.1|PERK6|3|6480484|6483774                                1.0
# AT3G01700|AT3G01700.1|AGP11|3|258879|259631                                  1.0
# AT1G24520|AT1G24520.1|BCP1|1|8688563|8689268                                 0.0
# AT1G23540|AT1G23540.1;AT1G23540.2|PERK12|1|8346...                           0.0
# AT1G10620|AT1G10620.1|PERK11|1|3509001|3512321                               1.0
# AT1G49270|AT1G49270.1|PERK7|1|18227122|18230330                              1.0
# AT4G34440|AT4G34440.2;AT4G34440.1|PERK5|4|16465...                           1.0
# AT2G24450|AT2G24450.1|FLA3|2|10392787|10393976                               1.0
# ...

# %%
df= data
df_for_clean = df[df[df.columns[-1]] == 1][df.columns[:-1]]
df_for_clean
# Out:
#                                                     gimme_15_BioProspector_w10_5  \
# AT3G57690|AT3G57690.1|AGP23|3|21384146|21384605                              1.0
# AT2G18470|AT2G18470.3;AT2G18470.1;AT2G18470.2;A...                           0.0
# AT4G33970|AT4G33970.1|PEX4|4|16278941|16282048                               1.0
# AT3G18810|AT3G18810.1|PERK6|3|6480484|6483774                                1.0
# AT3G01700|AT3G01700.1|AGP11|3|258879|259631                                  1.0
# AT1G24520|AT1G24520.1|BCP1|1|8688563|8689268                                 0.0
# AT1G23540|AT1G23540.1;AT1G23540.2|PERK12|1|8346...                           0.0
# AT1G10620|AT1G10620.1|PERK11|1|3509001|3512321                               1.0
# AT1G49270|AT1G49270.1|PERK7|1|18227122|18230330                              1.0
# AT4G34440|AT4G34440.2;AT4G34440.1|PERK5|4|16465...                           1.0
# AT2G24450|AT2G24450.1|FLA3|2|10392787|10393976                               1.0
# ...

# %%
p=4
df_for_clean.sum(axis=0) < 4
# df_for_clean[df_for_clean.sum(axis=0)<p]
# Out:
# gimme_15_BioProspector_w10_5               False
# gimme_33_AMD_Motif8                        False
# gimme_101_Improbizer_GTAGCTACGTTGGCTAA     False
# gimme_36_Homer_6_2                          True
# gimme_34_AMD_Motif9                        False
# gimme_114_MEME_5_w6                         True
# gimme_54_Homer_12_5                         True
# gimme_77_MDmodule_Motif.8.8                 True
# gimme_128_MEME_9_w8                         True
# gimme_89_MDmodule_Motif.10.10              False
# gimme_100_Improbizer_ACGAAAGAGAGAGAAAAG    False
# gimme_160_Weeder_1                          True
# gimme_45_Homer_10_1                        False
# gimme_113_MEME_4_w6                         True
# gimme_130_MEME_1_w10                       False
# gimme_28_AMD_Motif3                        False
# gimme_115_MEME_6_w6                         True
# gimme_21_BioProspector_w14_1               False
# gimme_58_Homer_14_4                         True
# ...
