# %%
from scipy.misc import *
import numpy as np
import glob

# %%
images = glob.glob("./ISIC_UDA-1_1/*.jpg")
images[0]
# Out:
# './ISIC_UDA-1_1\\ISIC_0000000.jpg'

# %%
my_matrix = imread(images[0],mode="L")

# %%
my_matrix.shape
# Out:
# (767, 1022)

# %%
[a,b]=my_matrix.shape
5 / 2
# Out:
# 2

# %%
a=[1,2,3,4,5]
a[0:6]
# Out:
# [1, 2, 3, 4, 5]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(my_matrix,cmap='gray')

# %%
plt.show()

# %%
plt.imshow(my_matrix[0:100,0:100],cmap='gray')
plt.show()

# %%
plt.imshow(my_matrix[0:200,0:200],cmap='gray')
plt.show()

# %%
plt.imshow(my_matrix[0:400,0:400],cmap='gray')
plt.show()

# %%
plt.imshow(my_matrix[200:400,200:400],cmap='gray')
plt.show()

# %%
i_width = 600
i_height = 600
my_m = imresize(my_matrix, (i_height, i_width))
my_m.shape
# Out:
# (600, 600)

# %%
plt.imshow(my_m,cmap='gray')
plt.show()
