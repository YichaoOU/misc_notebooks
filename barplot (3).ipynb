# %%
import pandas as pd

# %%
df = pd.read_csv("Hi-C-HindII-counting.result.csv",index_col=0)

# %%
df
# Out:
#                chr6   chr8  chr10  chr12   chr9   chr4  chr17   chr1   chr3  \
# 1.000000e-02  15137  14416  15276  14863  13748  17159  12563  18249  13441
# 1.000000e-03   8609   8304   8790   8640   7928  10349   7605  10385   6789
# 1.000000e-04   5721   5424   5837   5812   5309   7288   5290   6821   4063
# 1.000000e-05   4111   3901   4185   4087   3809   5546   3916   4937   2748
# 1.000000e-06   3146   2953   3232   3083   2894   4407   3081   3717   2011
# 1.000000e-07   2473   2346   2569   2365   2256   3608   2515   2945   1575
# 1.000000e-08   1966   1877   2050   1873   1834   2986   2114   2344   1271
#
#                chr2  ...   chrX  chr14  chr11   chr7  chr15  chr19  chr18  \
# 1.000000e-02  21892  ...   5857  11171  17614  14954  13168   7830   9564
# 1.000000e-03  13193  ...   2961   6021  11209   9080   7908   4940   5289
# 1.000000e-04   9050  ...   1797   3791   8126   6295   5494   3452   3422
# ...

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
for i in df.index.tolist():
    f, axs = plt.subplots(figsize=(15,5))
    plt.bar(np.arange(21),df.loc[i])
    plt.xticks(np.arange(21), df.columns.tolist())
    plt.title("Number of interaction at given threshold:"+str(i))
    plt.savefig("Prob"+str(i)+".png")

# %%
# Out:
# ['chr18',
#  'chr16',
#  'chr2',
#  'chr7',
#  'chr15',
#  'chr17',
#  'chr11',
#  'chr5',
#  'chr19',
#  'chr14',
#  'chr1',
#  'chr13',
#  'chr12',
#  'chr6',
#  'chr8',
#  'chr4',
#  'chr3',
#  'chr10',
#  'chr9']

# %%
# Out:
# chr18     239996
# chr16     311743
# chr2      923588
# chr7      652901
# chr15     322135
# chr17     271362
# chr11     497105
# chr5      661578
# chr19      79434
# chr14     471313
# chr1     1146070
# chr13     315492
# chr12     458764
# chr6      702146
# chr8      505659
# chr4      717811
# chr3      866912
# chr10     450145
# chr9      439792
# Name: 0.1, dtype: int64
