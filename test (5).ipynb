# %%
from PIL import Image
import cv2

# %%
P_image = Image.open("test_images/test1.jpg")
P_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x20DF579C978>

# %%
def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# %%
import numpy as np
a=load_image_into_numpy_array(P_image)

# %%
image_np_expanded = np.expand_dims(a, axis=0)
image_np_expanded
# Out:
# array([[[[ 64, 115, 158],
#          [ 65, 116, 159],
#          [ 65, 116, 159],
#          ...,
#          [110, 153, 188],
#          [113, 156, 191],
#          [110, 153, 187]],
#
#         [[ 65, 116, 159],
#          [ 65, 116, 159],
#          [ 66, 117, 160],
#          ...,
#          [110, 152, 190],
#          [112, 154, 192],
#          [109, 151, 189]],
#
#         [[ 66, 117, 160],
#          [ 66, 117, 160],
#          [ 66, 117, 160],
#          ...,
#          [108, 152, 191],
#          [110, 154, 193],
#          [108, 150, 190]],
#
#         ...,
#
#         [[117, 156, 185],
#          [117, 156, 185],
#          [118, 157, 186],
#          ...,
#          [142, 176, 203],
#          [142, 176, 203],
#          [142, 176, 203]],
#
#         [[117, 156, 185],
#          [117, 156, 185],
#          [118, 157, 186],
#          ...,
#          [142, 176, 203],
#          [142, 176, 203],
#          [142, 176, 203]],
#
#         [[116, 155, 184],
#          [117, 156, 185],
#          [117, 156, 185],
#          ...,
#          [142, 176, 203],
#          [142, 176, 203],
#          [142, 176, 203]]]], dtype=uint8)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.imshow(a)

# %%
frame = cv2.imread("test_images/test4.jpg")

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
r1 = np.array([150,0,130], dtype=np.uint8)
r2 = np.array([255, 100, 255], dtype=np.uint8)
mask1 = cv2.inRange(frame, r1, r2)
plt.imshow(mask1,cmap='gray')

# %%
image_np_expanded.shape
# Out:
# (1, 225, 225, 3)

# %%
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
np.expand_dims(frame, axis=0).shape
# Out:
# (1, 225, 225, 3)

# %%
Image.fromarray(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x20DF8E46AC8>
