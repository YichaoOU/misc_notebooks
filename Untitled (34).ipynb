# %%
import pandas as pd

# %%
df = pd.read_csv("chromHMM_motif_features.csv",index_col=0)

# %%
df.head()
# Out:
#                      state  STAT2_MOUSE.H11MO.0.A state.1  \
# name
# chr1:3052081-3052881    E4                     18      E4
# chr1:3109081-3109881    E4                     18      E4
# chr1:3332881-3333681    E4                      0      E4
# chr1:3472481-3474081    E4                     18      E4
# chr1:3521681-3522081    E7                      0      E7
#
#                       ZFP42_MOUSE.H11MO.0.A state.2  WT1_MOUSE.H11MO.0.B  \
# name
# chr1:3052081-3052881                     11      E4                    0
# chr1:3109081-3109881                      0      E4                    0
# chr1:3332881-3333681                      0      E4                   19
# chr1:3472481-3474081                      0      E4                   86
# chr1:3521681-3522081                      0      E7                   37
#
#                      state.3  TF2L1_MOUSE.H11MO.0.C state.4  \
# name
# chr1:3052081-3052881      E4                      0      E4
# ...

# %%
enhancer = ['E4','E8']
promoter = ['E6','E7']

# %%
PE_type = []
for x in df.index:
    if df.at[x,'state'] in enhancer:
        PE_type.append("enhancer")
    if df.at[x,'state'] in promoter:
        PE_type.append("promoter")
