# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

#input CSV files into dataframes, set column headers (same for all)
rand_forest = pd.read_csv("RF_filtering_result.csv",usecols = [0,3,6],header = None)
greedy = pd.read_csv("greedy_result.csv",usecols = [0,3,6],header = None)
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,3,6],header = None)
z_test = pd.read_csv("p_value_result.csv",usecols = [0,3,6],header = None)
tabu_pnpsc = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,3,6],header = None)
rilp = pd.read_csv("RILP_result.csv",usecols = [0,3,6],header = None)
random = pd.read_csv("random_motifs.csv",usecols = [0,3,6],header = None)
cols = ["Accuracy","Num_Motifs"]
greedy.columns = random.columns = enrichment.columns = z_test.columns = tabu_pnpsc.columns = rilp.columns = rand_forest.columns = ["Groups","Accuracy","Num_Motifs"]

#use melt to reshape the dataframe and attach id-variables
#displays sensitivity, specificity, etc across each group
rand_forest2 = pd.melt(rand_forest,value_vars=cols,id_vars="Groups")
greedy2 = pd.melt(greedy,value_vars=cols,id_vars="Groups")
enrichment2 = pd.melt(enrichment,value_vars=cols,id_vars="Groups")
z_test2 = pd.melt(z_test,value_vars=cols,id_vars="Groups")
tabu_pnpsc2 = pd.melt(tabu_pnpsc,value_vars=cols,id_vars="Groups")
rilp2 = pd.melt(rilp,value_vars=cols,id_vars="Groups")
random2 = pd.melt(random,value_vars=cols,id_vars="Groups")

#label each method so it will be clear which algorithm the data came from
rand_forest2["method"] = "Random_Forest"
greedy2["method"] = "Greedy"
enrichment2["method"] = "Enrichment"
z_test2["method"] = "Z-test"
tabu_pnpsc2["method"] = "Tabu_PNPSC"
rilp2["method"] = "RILP"
random2["method"] = "Random"

#coloring
custom_pal = {
"Random_Forest" : "#ff0000",
"Enrichment" : "#0000ff",
"Random" : "#228b22",
"Tabu_PNPSC" : "#a0450e",
"RILP" : "#ff9408",
"Z-test" : "#ff69b4",
"Greedy" : "#000000"
}


#now sort the methods we want to sort by:
#enrichment, random
rowsper = enrichment2.shape[0] / 2
enrichmentSORT = enrichment2.sort_values("value",ascending=False).groupby("variable").head(rowsper)
rowsper = random2.shape[0] / 2
randomSORT = random2.sort_values("value",ascending=False).groupby("variable").head(rowsper)

randomSORT
# Out:
#       Groups    variable      value  method
# 100    BRCA1  Num_Motifs  10.000000  Random
# 104   ZBTB33  Num_Motifs  10.000000  Random
# 65    POU2F2  Num_Motifs  10.000000  Random
# 64      ATF3  Num_Motifs  10.000000  Random
# 101    EP300  Num_Motifs  10.000000  Random
# 57       MYC  Num_Motifs  10.000000  Random
# 61       ETS  Num_Motifs   9.000000  Random
# 66      RXRA  Num_Motifs   9.000000  Random
# 74       SRF  Num_Motifs   9.000000  Random
# 62     NR3C1  Num_Motifs   9.000000  Random
# 106    NR2C2  Num_Motifs   9.000000  Random
# 75      RFX5  Num_Motifs   9.000000  Random
# 60       IRF  Num_Motifs   8.000000  Random
# 97    ZNF143  Num_Motifs   8.000000  Random
# 94      ELF1  Num_Motifs   8.000000  Random
# 73     CEBPB  Num_Motifs   7.000000  Random
# 109     MXI1  Num_Motifs   7.000000  Random
# 91   BHLHE40  Num_Motifs   7.000000  Random
# 84      PAX5  Num_Motifs   7.000000  Random
# 70     ESRRA  Num_Motifs   7.000000  Random
# 107     PBX3  Num_Motifs   7.000000  Random
# 68      MEF2  Num_Motifs   6.000000  Random
# 58      GATA  Num_Motifs   6.000000  Random
# 71      NFKB  Num_Motifs   6.000000  Random
# 80    TCF7L2  Num_Motifs   6.000000  Random
# 67      EGR1  Num_Motifs   5.000000  Random
# 76       SP1  Num_Motifs   5.000000  Random
# 87       HSF  Num_Motifs   5.000000  Random
# 89      REST  Num_Motifs   5.000000  Random
# 103    NANOG  Num_Motifs   5.000000  Random
# ..       ...         ...        ...     ...
# 14       MAF    Accuracy   0.732850  Random
# 19       SRF    Accuracy   0.721650  Random
# 44     PRDM1    Accuracy   0.715708  Random
# 18     CEBPB    Accuracy   0.713100  Random
# 17       AP1    Accuracy   0.700650  Random
# 32       HSF    Accuracy   0.700186  Random
# 1       HNF4    Accuracy   0.696750  Random
# 30    POU5F1    Accuracy   0.691132  Random
# 52      PBX3    Accuracy   0.685339  Random
# 10    POU2F2    Accuracy   0.675700  Random
# 7      NR3C1    Accuracy   0.673950  Random
# 26      TATA    Accuracy   0.672200  Random
# 20      RFX5    Accuracy   0.659000  Random
# 21       SP1    Accuracy   0.658950  Random
# 15     ESRRA    Accuracy   0.658050  Random
# 22      FOXA    Accuracy   0.652900  Random
# 29      PAX5    Accuracy   0.649850  Random
# 42    ZNF143    Accuracy   0.643450  Random
# 11      RXRA    Accuracy   0.633500  Random
# 5        IRF    Accuracy   0.629950  Random
# 3       GATA    Accuracy   0.627100  Random
# 50      BATF    Accuracy   0.617550  Random
# 47     TCF12    Accuracy   0.611950  Random
# 13      MEF2    Accuracy   0.610500  Random
# 8       STAT    Accuracy   0.609000  Random
# 48     NANOG    Accuracy   0.603600  Random
# 31      TAL1    Accuracy   0.570600  Random
# 46     EP300    Accuracy   0.564900  Random
# 53      HEY1    Accuracy   0.560350  Random
# 33      ZEB1    Accuracy   0.542407  Random
#
# [110 rows x 4 columns]

# %%
#create dirs for the two different types of line graphs: evaluation on 3 algorithms vs. on all
#just to keep from being cluttered
if not os.path.exists("3algs"):
	os.makedirs("3algs")
merged = [randomSORT,enrichment2,rand_forest2]
result3RVAL = pd.concat(merged)
path = "/home/osboxes/visualization/3algs/result3RVAL.csv"
merged = [enrichmentSORT,random2,rand_forest2]
result3EVAL = pd.concat(merged)
result3EVAL.to_csv(path)
if not os.path.exists("allalgs"):
	os.makedirs("allalgs")
merged = [randomSORT,rand_forest2,greedy2,enrichment2,z_test2,tabu_pnpsc2,rilp2]
resultRVAL = pd.concat(merged)
path = "/home/osboxes/visualization/allalgs/resultRVAL.csv"
resultRVAL.to_csv(path)

result3EVAL
# Out:
#       Groups    variable  value         method
# 81      TATA  Num_Motifs   10.0     Enrichment
# 101    EP300  Num_Motifs   10.0     Enrichment
# 72       AP1  Num_Motifs   10.0     Enrichment
# 89      REST  Num_Motifs   10.0     Enrichment
# 95      CTCF  Num_Motifs   10.0     Enrichment
# 57       MYC  Num_Motifs   10.0     Enrichment
# 61       ETS  Num_Motifs    9.0     Enrichment
# 55       E2F  Num_Motifs    8.0     Enrichment
# 63      STAT  Num_Motifs    7.0     Enrichment
# 67      EGR1  Num_Motifs    7.0     Enrichment
# 102    TCF12  Num_Motifs    6.0     Enrichment
# 58      GATA  Num_Motifs    6.0     Enrichment
# 60       IRF  Num_Motifs    6.0     Enrichment
# 62     NR3C1  Num_Motifs    6.0     Enrichment
# 84      PAX5  Num_Motifs    5.0     Enrichment
# 66      RXRA  Num_Motifs    5.0     Enrichment
# 77      FOXA  Num_Motifs    5.0     Enrichment
# 56      HNF4  Num_Motifs    5.0     Enrichment
# 78       YY1  Num_Motifs    5.0     Enrichment
# 71      NFKB  Num_Motifs    4.0     Enrichment
# 79      SIX5  Num_Motifs    4.0     Enrichment
# 97    ZNF143  Num_Motifs    4.0     Enrichment
# 96      NFE2  Num_Motifs    4.0     Enrichment
# 64      ATF3  Num_Motifs    4.0     Enrichment
# 70     ESRRA  Num_Motifs    4.0     Enrichment
# 103    NANOG  Num_Motifs    4.0     Enrichment
# 104   ZBTB33  Num_Motifs    4.0     Enrichment
# 94      ELF1  Num_Motifs    3.0     Enrichment
# 107     PBX3  Num_Motifs    3.0     Enrichment
# 105     BATF  Num_Motifs    3.0     Enrichment
# ..       ...         ...    ...            ...
# 80    TCF7L2  Num_Motifs    5.0  Random_Forest
# 81      TATA  Num_Motifs    6.0  Random_Forest
# 82       NFY  Num_Motifs    1.0  Random_Forest
# 83     SREBP  Num_Motifs    3.0  Random_Forest
# 84      PAX5  Num_Motifs    3.0  Random_Forest
# 85    POU5F1  Num_Motifs    1.0  Random_Forest
# 86      TAL1  Num_Motifs    3.0  Random_Forest
# 87       HSF  Num_Motifs    3.0  Random_Forest
# 88      ZEB1  Num_Motifs    4.0  Random_Forest
# 89      REST  Num_Motifs    3.0  Random_Forest
# 90      SPI1  Num_Motifs    1.0  Random_Forest
# 91   BHLHE40  Num_Motifs    5.0  Random_Forest
# 92      EBF1  Num_Motifs    5.0  Random_Forest
# 93    ZBTB7A  Num_Motifs    5.0  Random_Forest
# 94      ELF1  Num_Motifs    5.0  Random_Forest
# 95      CTCF  Num_Motifs    2.0  Random_Forest
# 96      NFE2  Num_Motifs    5.0  Random_Forest
# 97    ZNF143  Num_Motifs    3.0  Random_Forest
# 98      NRF1  Num_Motifs    5.0  Random_Forest
# 99     PRDM1  Num_Motifs    1.0  Random_Forest
# 100    BRCA1  Num_Motifs    7.0  Random_Forest
# 101    EP300  Num_Motifs    7.0  Random_Forest
# 102    TCF12  Num_Motifs    7.0  Random_Forest
# 103    NANOG  Num_Motifs    3.0  Random_Forest
# 104   ZBTB33  Num_Motifs    7.0  Random_Forest
# 105     BATF  Num_Motifs    3.0  Random_Forest
# 106    NR2C2  Num_Motifs    3.0  Random_Forest
# 107     PBX3  Num_Motifs    5.0  Random_Forest
# 108     HEY1  Num_Motifs    5.0  Random_Forest
# 109     MXI1  Num_Motifs    7.0  Random_Forest
#
# [330 rows x 4 columns]

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot Accuracy ALPHABETICAL
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=result3RVAL[result3RVAL['variable']=="Accuracy"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Accuracy',fontsize=30)
ax.set_ylim([0.2, 1])
legend = plt.legend(loc=3, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/3algs/AccuracyOnThree_RVAL.png"
plt.savefig(path,dpi=300)

f

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot num motifs, sort by random algo
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=result3RVAL[result3RVAL['variable']=="Num_Motifs"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Num_motifs',fontsize=30)
ax.set_ylim([0, 20])
legend = plt.legend(loc=0, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/3algs/NumMotifsOnThree_RVAL.png"
plt.savefig(path,dpi=300)

f

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot Accuracy ALPHABETICAL
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=result3EVAL[result3EVAL['variable']=="Accuracy"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Accuracy',fontsize=30)
ax.set_ylim([0.2, 1])
legend = plt.legend(loc=3, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/3algs/AccuracyOnThree_EVAL.png"
plt.savefig(path,dpi=300)

f

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot num motifs, sort by random algo
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=result3EVAL[result3EVAL['variable']=="Num_Motifs"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Num_motifs',fontsize=30)
ax.set_ylim([0, 20])
legend = plt.legend(loc=0, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/3algs/NumMotifsOnThree_EVAL.png"
plt.savefig(path,dpi=300)

f

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot Accuracy ALPHABETICAL
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=resultRVAL[resultRVAL['variable']=="Accuracy"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Accuracy',fontsize=30)
ax.set_ylim([0.2, 1])
legend = plt.legend(loc=3, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/allalgs/AccuracyOnAll_RVAL.png"
plt.savefig(path,dpi=300)

f

# %%
#FIRST TWO: sort by random on 3, num motifs and accuracy
#plot Accuracy ALPHABETICAL
f, ax = plt.subplots(figsize=(25,15))
g = sns.pointplot(x="Groups",jitter=0.3,alpha=0.7,size=15,y="value",hue="method",data=resultRVAL[resultRVAL['variable']=="Num_Motifs"],palette=custom_pal)
g.set_xticklabels(g.get_xticklabels(),rotation=30)
handles, labels = ax.get_legend_handles_labels()
ax.tick_params(labelsize=10)
ax.set_xlabel('')
ax.set_ylabel('Num_motifs',fontsize=30)
ax.set_ylim([0, 20])
legend = plt.legend(loc=2, prop={'size': 20},frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('white')
path = "/home/osboxes/visualization/allalgs/NumMotifsOnAll_RVAL.png"
plt.savefig(path,dpi=300)

f
