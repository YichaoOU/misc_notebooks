# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,1,2,3,6],header = None)
enrichment.columns = ["Groups","enrichment-Sensitivity","enrichment-Specificity","enrichment-Accuracy","Num_motifs"]
enrichment.set_index("Groups",inplace=True)
enrichment['enrichment-Specificity'] = 1- enrichment['enrichment-Specificity']
enrichment['enrichment-Accuracy'] = 1- enrichment['enrichment-Accuracy']

greedy = pd.read_csv("greedy_result.csv",usecols = [0,1,2,3,6],header = None)
greedy.columns = ["Groups","greedy-Sensitivity","greedy-Specificity","greedy-Accuracy","Num_motifs"]
greedy.set_index("Groups",inplace=True)
greedy['greedy-Specificity'] = 1- greedy['greedy-Specificity']
greedy['greedy-Accuracy'] = 1- greedy['greedy-Accuracy']

RILP = pd.read_csv("RILP_result.csv",usecols = [0,1,2,3,6],header = None)
RILP.columns = ["Groups","RILP-Sensitivity","RILP-Specificity","RILP-Accuracy","Num_motifs"]
RILP.set_index("Groups",inplace=True)
RILP['RILP-Specificity'] = 1- RILP['RILP-Specificity']
RILP['RILP-Accuracy'] = 1- RILP['RILP-Accuracy']
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,1,2,3,6],header = None)
Tabu_PNPSC.columns = ["Groups","Tabu_PNPSC-Sensitivity","Tabu_PNPSC-Specificity","Tabu_PNPSC-Accuracy","Num_motifs"]
Tabu_PNPSC.set_index("Groups",inplace=True)
Tabu_PNPSC['Tabu_PNPSC-Specificity'] = 1- Tabu_PNPSC['Tabu_PNPSC-Specificity']
Tabu_PNPSC['Tabu_PNPSC-Accuracy'] = 1- Tabu_PNPSC['Tabu_PNPSC-Accuracy']
random_selection = pd.read_csv("Random_motifs_result.csv",usecols = [0,1,2,3,6],header = None)
random_selection.columns = ["Groups","random_selection-Sensitivity","random_selection-Specificity","random_selection-Accuracy","Num_motifs"]
random_selection.set_index("Groups",inplace=True)
random_selection['random_selection-Specificity'] = 1- random_selection['random_selection-Specificity']
random_selection['random_selection-Accuracy'] = 1- random_selection['random_selection-Accuracy']

table1 = pd.concat([enrichment,greedy,RILP,Tabu_PNPSC,random_selection],axis=1)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pylab
enrichment = pd.read_csv("enrichment_MS_summary.csv",usecols = [0,1,2,3,6],header = None)
enrichment.columns = ["Groups","Sensitivity","Specificity","Accuracy","Num_motifs"]
enrichment.set_index("Groups",inplace=True)
enrichment['Specificity'] = 1- enrichment['Specificity']
enrichment['Accuracy'] = 1- enrichment['Accuracy']

greedy = pd.read_csv("greedy_result.csv",usecols = [0,1,2,3,6],header = None)
greedy.columns = ["Groups","Sensitivity","Specificity","Accuracy","Num_motifs"]
greedy.set_index("Groups",inplace=True)
greedy['Specificity'] = 1- greedy['Specificity']
greedy['Accuracy'] = 1- greedy['Accuracy']

RILP = pd.read_csv("RILP_result.csv",usecols = [0,1,2,3,6],header = None)
RILP.columns = ["Groups","Sensitivity","Specificity","Accuracy","Num_motifs"]
RILP.set_index("Groups",inplace=True)
RILP['Specificity'] = 1- RILP['Specificity']
RILP['Accuracy'] = 1- RILP['Accuracy']
Tabu_PNPSC = pd.read_csv("Tabu_PNPSC_result.csv",usecols = [0,1,2,3,6],header = None)
Tabu_PNPSC.columns = ["Groups","Sensitivity","Specificity","Accuracy","Num_motifs"]
Tabu_PNPSC.set_index("Groups",inplace=True)
Tabu_PNPSC['Specificity'] = 1- Tabu_PNPSC['Specificity']
Tabu_PNPSC['Accuracy'] = 1- Tabu_PNPSC['Accuracy']
random_selection = pd.read_csv("Random_motifs_result.csv",usecols = [0,1,2,3,6],header = None)
random_selection.columns = ["Groups","Sensitivity","Specificity","Accuracy","Num_motifs"]
random_selection.set_index("Groups",inplace=True)
random_selection['Specificity'] = 1- random_selection['Specificity']
random_selection['Accuracy'] = 1- random_selection['Accuracy']

# %%
table_ForeCov = pd.concat([enrichment["Sensitivity"],greedy["Sensitivity"],RILP["Sensitivity"],Tabu_PNPSC["Sensitivity"]],axis=1)
table_ForeCov.columns = ['Enrch','Grdy','RILP','TABU']
table_ForeCov = table_ForeCov*100
table_ForeCov = table_ForeCov.round(1)
table_ForeCov['max'] = table_ForeCov.max(axis=1)
table_ForeCov = table_ForeCov.fillna("NA")
table_ForeCov = table_ForeCov.sort_values('Enrch')

# fig = pylab.figure(figsize=(5,15))
# sns.heatmap(table_ForeCov,annot=True,cmap="YlOrRd")
table_ForeCov.to_csv("table_forecov.tsv",sep="\t")

# %%
header = """

\\begin{table}[]
\centering
\def\\arraystretch{1.3}
\caption{Foreground coverage(\%) comparison across 55 factors}
\label{my-label}
\\begin{tabular}{|l|c|c|c|c|}
\hline
Factor  & Enrch               & Grdy                & RILP                & TABU                \\\\ \hline


"""

def print_table(file):
	lines = open(file).readlines()
	num_max_count = [0,0,0,0]
	for line in lines[1:]:
		line = line.strip().split("\t")
		max_value = line[-1]
		outline = line[0] + "\t\t& "
		count = 0
		for ele in line[1:-1]:
			if ele == "NA":
				outline += ele + "\t\t& "
				continue
			if float(ele) == float(max_value):
				outline += "{\\textbf{my_value}}".replace("my_value",max_value) + "\t\t& "
# 				print count,line
				num_max_count[count] += 1
			else:
				outline += ele + "\t\t& "
			count +=1
		outline = outline[:-2]
		outline += "\\\\ \hline"
		print outline
	outline = map(lambda x:str(x) + "\t\t& ",num_max_count)
# 	print outline
	outline = "Winning Times 		& "+ "".join(outline)[:-2] + "\\\\ \hline"
	print outline
print_table("table_forecov.tsv")
# Out:
# SREBP		& 26.5		& 69.4		& {\textbf{76.1}}		& 64.9		\\ \hline
# CEBPB		& 28.2		& 55.4		& {\textbf{63.4}}		& 61.2		\\ \hline
# BRCA1		& 29.6		& 61.5		& {\textbf{66.1}}		& 46.1		\\ \hline
# RFX5		& 37.8		& 64.0		& {\textbf{71.2}}		& 51.3		\\ \hline
# ZEB1		& 40.6		& 72.6		& {\textbf{76.9}}		& 71.4		\\ \hline
# BATF		& 41.6		& 48.9		& {\textbf{60.9}}		& 43.9		\\ \hline
# TCF7L2		& 44.5		& {\textbf{81.5}}		& 80.9		& 68.0		\\ \hline
# MXI1		& 45.5		& {\textbf{80.8}}		& 79.4		& 57.5		\\ \hline
# ZNF143		& 47.2		& 47.8		& {\textbf{52.3}}		& 39.8		\\ \hline
# SIX5		& 47.5		& 79.1		& {\textbf{80.2}}		& 78.9		\\ \hline
# GATA		& 48.0		& {\textbf{79.9}}		& 68.8		& 56.9		\\ \hline
# FOXA		& 48.2		& 54.6		& {\textbf{64.0}}		& 49.4		\\ \hline
# ZBTB7A		& 48.3		& {\textbf{92.6}}		& 82.7		& 79.4		\\ \hline
# NANOG		& 49.2		& 59.6		& {\textbf{69.1}}		& 35.0		\\ \hline
# MEF2		& 49.4		& 55.0		& {\textbf{65.2}}		& 35.1		\\ \hline
# RXRA		& 51.9		& 68.8		& {\textbf{72.0}}		& 61.7		\\ \hline
# SRF		& 52.1		& 69.1		& {\textbf{72.9}}		& 64.6		\\ \hline
# PBX3		& 54.1		& {\textbf{62.7}}		& 62.4		& 37.3		\\ \hline
# TAL1		& 55.3		& 58.6		& {\textbf{64.1}}		& 47.3		\\ \hline
# STAT		& 55.6		& 68.1		& {\textbf{82.5}}		& 67.8		\\ \hline
# EP300		& 57.0		& 52.9		& {\textbf{61.4}}		& 41.6		\\ \hline
# POU2F2		& 58.1		& 67.8		& 75.7		& {\textbf{100.0}}		\\ \hline
# BHLHE40		& 58.2		& 63.1		& {\textbf{70.4}}		& 46.8		\\ \hline
# HEY1		& 59.3		& 71.6		& 73.8		& {\textbf{100.0}}		\\ \hline
# MAF		& 60.0		& 73.3		& {\textbf{82.0}}		& 72.4		\\ \hline
# EBF1		& 61.9		& 70.4		& 76.4		& {\textbf{100.0}}		\\ \hline
# SP1		& 63.1		& 65.2		& 69.3		& {\textbf{100.0}}		\\ \hline
# IRF		& 63.6		& 72.4		& {\textbf{72.5}}		& 55.1		\\ \hline
# PAX5		& 64.6		& 68.6		& {\textbf{73.2}}		& 65.0		\\ \hline
# ZBTB33		& 65.2		& {\textbf{75.1}}		& 73.0		& 70.4		\\ \hline
# HNF4		& 65.2		& 69.8		& {\textbf{76.7}}		& 65.4		\\ \hline
# TCF12		& 65.6		& 67.5		& {\textbf{80.3}}		& 66.5		\\ \hline
# AP1		& 66.0		& 73.7		& {\textbf{75.3}}		& NA		\\ \hline
# ESRRA		& 66.6		& {\textbf{71.6}}		& 69.9		& 60.2		\\ \hline
# NR2C2		& 70.5		& {\textbf{90.8}}		& {\textbf{90.8}}		& 78.0		\\ \hline
# NFKB		& 70.6		& {\textbf{79.4}}		& 75.9		& 72.5		\\ \hline
# NR3C1		& 70.9		& 73.8		& 73.4		& {\textbf{90.5}}		\\ \hline
# ATF3		& 71.2		& 80.3		& {\textbf{81.5}}		& 78.6		\\ \hline
# POU5F1		& {\textbf{71.8}}		& {\textbf{71.8}}		& {\textbf{71.8}}		& {\textbf{71.8}}		\\ \hline
# TATA		& 73.2		& {\textbf{80.0}}		& 76.8		& NA		\\ \hline
# SPI1		& 75.3		& 80.2		& {\textbf{90.6}}		& 80.6		\\ \hline
# MYC		& 76.0		& 80.0		& {\textbf{81.8}}		& NA		\\ \hline
# PRDM1		& 77.1		& {\textbf{83.6}}		& 83.2		& 76.5		\\ \hline
# ELF1		& 77.4		& 84.0		& {\textbf{86.3}}		& 81.6		\\ \hline
# YY1		& 78.3		& 80.3		& {\textbf{80.6}}		& 72.5		\\ \hline
# REST		& 82.5		& {\textbf{84.1}}		& 81.4		& 83.0		\\ \hline
# TFAP2		& 83.9		& {\textbf{91.4}}		& 90.9		& 76.4		\\ \hline
# EGR1		& 84.1		& 89.5		& {\textbf{89.8}}		& 84.5		\\ \hline
# E2F		& 84.1		& {\textbf{85.0}}		& 82.6		& 81.9		\\ \hline
# NFY		& 84.3		& 87.8		& {\textbf{88.1}}		& {\textbf{88.1}}		\\ \hline
# NFE2		& 84.5		& {\textbf{93.2}}		& {\textbf{93.2}}		& 93.1		\\ \hline
# CTCF		& 86.1		& {\textbf{86.6}}		& {\textbf{86.6}}		& NA		\\ \hline
# ETS		& 86.9		& {\textbf{89.7}}		& 89.6		& 82.8		\\ \hline
# NRF1		& {\textbf{95.7}}		& 93.5		& 93.5		& 93.7		\\ \hline
# HSF		& {\textbf{100.0}}		& 57.8		& 61.2		& 39.9		\\ \hline
# Winning Times 		& 3		& 18		& 34		& 7		\\ \hline

# %%
table_ForeCov = pd.concat([enrichment["Specificity"],greedy["Specificity"],RILP["Specificity"],Tabu_PNPSC["Specificity"]],axis=1)
table_ForeCov.columns = ['Enrch','Grdy','RILP','TABU']
table_ForeCov = table_ForeCov*100
table_ForeCov = table_ForeCov.round(1)
table_ForeCov['min'] = table_ForeCov.min(axis=1)
table_ForeCov = table_ForeCov.fillna("NA")
table_ForeCov = table_ForeCov.sort_values('Enrch',ascending=False)
table_ForeCov.to_csv("temp.tsv",sep="\t")
# print header
print_table("temp.tsv")
# Out:
# HSF		& 100.0		& 16.9		& 20.1		& {\textbf{10.2}}		\\ \hline
# NANOG		& 27.6		& 26.7		& 33.2		& {\textbf{12.6}}		\\ \hline
# EP300		& 27.5		& 25.2		& 31.9		& {\textbf{16.9}}		\\ \hline
# SP1		& 26.8		& {\textbf{22.8}}		& 26.3		& 100.0		\\ \hline
# MEF2		& 26.7		& 26.8		& 37.6		& {\textbf{14.8}}		\\ \hline
# ESRRA		& 25.8		& 26.4		& 25.2		& {\textbf{19.0}}		\\ \hline
# NFKB		& 25.4		& 27.6		& 22.5		& {\textbf{17.3}}		\\ \hline
# TCF12		& 22.6		& {\textbf{20.5}}		& 27.2		& {\textbf{20.5}}		\\ \hline
# NR3C1		& {\textbf{22.0}}		& 24.1		& 24.6		& 74.1		\\ \hline
# MYC		& 20.8		& {\textbf{18.2}}		& 19.5		& NA		\\ \hline
# PAX5		& 20.6		& 16.1		& 19.5		& {\textbf{14.1}}		\\ \hline
# GATA		& {\textbf{20.4}}		& 45.4		& 35.6		& 29.0		\\ \hline
# RXRA		& {\textbf{20.2}}		& 29.7		& 28.9		& 23.8		\\ \hline
# POU2F2		& {\textbf{19.8}}		& 24.8		& 31.0		& 100.0		\\ \hline
# SPI1		& 19.8		& {\textbf{16.2}}		& 21.7		& {\textbf{16.2}}		\\ \hline
# IRF		& 19.2		& 26.8		& 28.9		& {\textbf{13.7}}		\\ \hline
# MAF		& 17.4		& 9.0		& 14.0		& {\textbf{8.6}}		\\ \hline
# REST		& {\textbf{16.2}}		& 19.0		& 16.8		& 16.4		\\ \hline
# ETS		& 15.6		& 16.5		& 16.5		& {\textbf{8.3}}		\\ \hline
# PBX3		& 15.4		& 20.1		& 19.5		& {\textbf{7.4}}		\\ \hline
# EBF1		& {\textbf{15.4}}		& 20.0		& 25.1		& 100.0		\\ \hline
# YY1		& 15.0		& 18.0		& 15.8		& {\textbf{9.9}}		\\ \hline
# FOXA		& 15.0		& 16.9		& 21.1		& {\textbf{10.8}}		\\ \hline
# NR2C2		& 14.6		& 16.9		& 16.9		& {\textbf{7.1}}		\\ \hline
# PRDM1		& 14.5		& 18.2		& 17.6		& {\textbf{14.0}}		\\ \hline
# CTCF		& 14.4		& {\textbf{10.5}}		& {\textbf{10.5}}		& NA		\\ \hline
# TAL1		& 13.8		& 17.0		& 12.5		& {\textbf{7.0}}		\\ \hline
# TFAP2		& 13.3		& 21.2		& 21.0		& {\textbf{9.1}}		\\ \hline
# BATF		& 13.2		& 12.5		& 15.5		& {\textbf{8.2}}		\\ \hline
# STAT		& {\textbf{13.2}}		& 22.9		& 59.8		& 30.2		\\ \hline
# TCF7L2		& {\textbf{12.8}}		& 31.0		& 31.2		& 21.1		\\ \hline
# ZNF143		& 12.5		& 13.3		& 15.8		& {\textbf{11.9}}		\\ \hline
# BHLHE40		& 12.3		& 10.9		& 13.6		& {\textbf{2.3}}		\\ \hline
# TATA		& {\textbf{12.3}}		& 15.9		& 14.8		& NA		\\ \hline
# POU5F1		& {\textbf{12.2}}		& {\textbf{12.2}}		& {\textbf{12.2}}		& {\textbf{12.2}}		\\ \hline
# HNF4		& 11.8		& 13.3		& 17.1		& {\textbf{9.8}}		\\ \hline
# E2F		& 10.7		& 13.5		& 12.0		& {\textbf{9.6}}		\\ \hline
# SRF		& {\textbf{10.3}}		& 17.4		& 22.0		& 13.4		\\ \hline
# ELF1		& {\textbf{9.9}}		& 13.5		& 13.4		& 10.6		\\ \hline
# EGR1		& 9.6		& 14.4		& 13.7		& {\textbf{9.1}}		\\ \hline
# ZEB1		& {\textbf{9.5}}		& 15.0		& 17.1		& 14.2		\\ \hline
# AP1		& {\textbf{9.5}}		& 11.3		& 13.7		& NA		\\ \hline
# RFX5		& {\textbf{9.0}}		& 23.3		& 30.7		& 14.6		\\ \hline
# NFE2		& {\textbf{8.7}}		& 11.8		& 12.0		& 11.8		\\ \hline
# ATF3		& {\textbf{7.8}}		& 12.5		& 9.1		& 8.7		\\ \hline
# HEY1		& {\textbf{7.2}}		& 16.3		& 15.6		& 100.0		\\ \hline
# MXI1		& {\textbf{7.1}}		& 18.8		& 14.5		& 7.9		\\ \hline
# NRF1		& 6.0		& {\textbf{2.5}}		& {\textbf{2.5}}		& 2.6		\\ \hline
# ZBTB33		& 6.0		& 10.2		& 7.4		& {\textbf{5.8}}		\\ \hline
# SREBP		& {\textbf{5.5}}		& 11.1		& 13.3		& 8.1		\\ \hline
# ZBTB7A		& {\textbf{4.6}}		& 14.3		& 9.9		& 7.4		\\ \hline
# NFY		& 4.6		& {\textbf{4.1}}		& 4.4		& {\textbf{4.1}}		\\ \hline
# SIX5		& {\textbf{2.2}}		& 16.8		& 10.7		& 13.5		\\ \hline
# CEBPB		& {\textbf{2.1}}		& 5.3		& 7.0		& 5.3		\\ \hline
# BRCA1		& {\textbf{0.3}}		& 8.6		& 12.3		& 2.9		\\ \hline
# Winning Times 		& 24		& 8		& 3		& 28		\\ \hline

# %%
table_ForeCov = pd.concat([enrichment["Accuracy"],greedy["Accuracy"],RILP["Accuracy"],Tabu_PNPSC["Accuracy"]],axis=1)
table_ForeCov.columns = ['Enrch','Grdy','RILP','TABU']
table_ForeCov = table_ForeCov*100
table_ForeCov = table_ForeCov.round(1)
table_ForeCov['min'] = table_ForeCov.min(axis=1)
table_ForeCov = table_ForeCov.fillna("NA")
table_ForeCov = table_ForeCov.sort_values('Enrch',ascending=False)
table_ForeCov.to_csv("temp.tsv",sep="\t")
# print header
print_table("temp.tsv")
# Out:
# HSF		& 50.0		& 29.6		& {\textbf{29.5}}		& 35.2		\\ \hline
# SREBP		& 39.5		& 20.8		& {\textbf{18.6}}		& 21.6		\\ \hline
# NANOG		& 39.2		& 33.6		& {\textbf{32.1}}		& 38.8		\\ \hline
# MEF2		& 38.6		& {\textbf{35.9}}		& 36.2		& 39.9		\\ \hline
# CEBPB		& 37.0		& 25.0		& {\textbf{21.8}}		& 22.1		\\ \hline
# GATA		& 36.2		& {\textbf{32.8}}		& 33.4		& 36.1		\\ \hline
# BATF		& 35.8		& 31.8		& {\textbf{27.3}}		& 32.2		\\ \hline
# RFX5		& 35.6		& {\textbf{29.7}}		& {\textbf{29.7}}		& 31.6		\\ \hline
# BRCA1		& 35.4		& 23.5		& {\textbf{23.1}}		& 28.4		\\ \hline
# EP300		& {\textbf{35.2}}		& 36.2		& {\textbf{35.2}}		& 37.6		\\ \hline
# ZEB1		& 34.4		& 21.2		& {\textbf{20.1}}		& 21.4		\\ \hline
# TCF7L2		& 34.2		& {\textbf{24.8}}		& 25.2		& 26.5		\\ \hline
# RXRA		& 34.1		& 30.4		& {\textbf{28.4}}		& 31.0		\\ \hline
# FOXA		& 33.4		& 31.2		& {\textbf{28.5}}		& 30.7		\\ \hline
# ZNF143		& 32.7		& 32.8		& {\textbf{31.8}}		& 36.0		\\ \hline
# SP1		& 31.9		& 28.8		& {\textbf{28.5}}		& 50.0		\\ \hline
# POU2F2		& 30.9		& 28.5		& {\textbf{27.6}}		& 50.0		\\ \hline
# MXI1		& 30.8		& 19.0		& {\textbf{17.5}}		& 25.2		\\ \hline
# PBX3		& 30.7		& 28.7		& {\textbf{28.6}}		& 35.1		\\ \hline
# ESRRA		& 29.6		& {\textbf{27.4}}		& 27.7		& 29.4		\\ \hline
# TAL1		& 29.2		& 29.2		& {\textbf{24.2}}		& 29.8		\\ \hline
# SRF		& 29.1		& {\textbf{24.2}}		& 24.5		& 24.4		\\ \hline
# STAT		& 28.8		& {\textbf{27.4}}		& 38.6		& 31.2		\\ \hline
# MAF		& 28.7		& 17.8		& {\textbf{16.0}}		& 18.1		\\ \hline
# TCF12		& 28.5		& 26.5		& {\textbf{23.5}}		& 27.0		\\ \hline
# ZBTB7A		& 28.2		& {\textbf{10.9}}		& 13.6		& 14.0		\\ \hline
# PAX5		& 28.0		& 23.7		& {\textbf{23.2}}		& 24.5		\\ \hline
# IRF		& 27.8		& {\textbf{27.2}}		& 28.2		& 29.3		\\ \hline
# NFKB		& 27.4		& 24.1		& 23.3		& {\textbf{22.4}}		\\ \hline
# SIX5		& 27.3		& 18.8		& {\textbf{15.3}}		& 17.3		\\ \hline
# BHLHE40		& 27.1		& 23.9		& {\textbf{21.6}}		& 27.7		\\ \hline
# EBF1		& 26.7		& 24.8		& {\textbf{24.4}}		& 50.0		\\ \hline
# NR3C1		& 25.5		& {\textbf{25.1}}		& 25.6		& 41.8		\\ \hline
# HEY1		& 23.9		& 22.4		& {\textbf{20.9}}		& 50.0		\\ \hline
# HNF4		& 23.3		& 21.8		& {\textbf{20.2}}		& 22.2		\\ \hline
# MYC		& 22.4		& 19.1		& {\textbf{18.8}}		& NA		\\ \hline
# SPI1		& 22.3		& 18.0		& {\textbf{15.5}}		& 17.8		\\ \hline
# NR2C2		& 22.0		& {\textbf{13.0}}		& {\textbf{13.0}}		& 14.6		\\ \hline
# AP1		& 21.7		& {\textbf{18.8}}		& 19.2		& NA		\\ \hline
# ZBTB33		& 20.4		& 17.5		& {\textbf{17.2}}		& 17.7		\\ \hline
# POU5F1		& {\textbf{20.2}}		& {\textbf{20.2}}		& {\textbf{20.2}}		& {\textbf{20.2}}		\\ \hline
# TATA		& 19.6		& {\textbf{17.9}}		& 19.0		& NA		\\ \hline
# PRDM1		& 18.7		& 17.3		& {\textbf{17.2}}		& 18.7		\\ \hline
# YY1		& 18.4		& 18.8		& {\textbf{17.6}}		& 18.7		\\ \hline
# ATF3		& 18.3		& 16.1		& {\textbf{13.8}}		& 15.1		\\ \hline
# REST		& 16.9		& 17.4		& 17.7		& {\textbf{16.7}}		\\ \hline
# ELF1		& 16.3		& 14.7		& {\textbf{13.6}}		& 14.5		\\ \hline
# TFAP2		& {\textbf{14.7}}		& 14.9		& 15.1		& 16.4		\\ \hline
# ETS		& 14.4		& 13.4		& 13.5		& {\textbf{12.8}}		\\ \hline
# CTCF		& 14.2		& {\textbf{12.0}}		& {\textbf{12.0}}		& NA		\\ \hline
# E2F		& {\textbf{13.3}}		& 14.3		& 14.7		& 13.8		\\ \hline
# EGR1		& 12.7		& 12.5		& {\textbf{11.9}}		& 12.3		\\ \hline
# NFE2		& 12.1		& {\textbf{9.3}}		& 9.4		& 9.4		\\ \hline
# NFY		& 10.2		& 8.2		& 8.1		& {\textbf{8.0}}		\\ \hline
# NRF1		& 5.1		& {\textbf{4.5}}		& {\textbf{4.5}}		& {\textbf{4.5}}		\\ \hline
# Winning Times 		& 4		& 17		& 37		& 6		\\ \hline

# %%
table_ForeCov = pd.concat([enrichment["Num_motifs"],greedy["Num_motifs"],RILP["Num_motifs"],Tabu_PNPSC["Num_motifs"]],axis=1)
table_ForeCov.columns = ['Enrch','Grdy','RILP','TABU']
table_ForeCov = table_ForeCov
# table_ForeCov = table_ForeCov.round(1)
# import numpy as np
table_ForeCov['min'] = table_ForeCov.min(axis=1).astype(int)
# table_ForeCov['TABU'] = table_ForeCov['TABU'].astype(np.int)
table_ForeCov = table_ForeCov.fillna("NA")
table_ForeCov = table_ForeCov.sort_values('Enrch',ascending=False)
table_ForeCov.to_csv("temp.tsv",sep="\t")
table_ForeCov
# print header
print_table("temp.tsv")
# Out:
# AP1		& 10		& {\textbf{1}}		& {\textbf{1}}		& NA		\\ \hline
# TATA		& 10		& {\textbf{2}}		& {\textbf{2}}		& NA		\\ \hline
# REST		& 10		& {\textbf{2}}		& {\textbf{2}}		& 3.0		\\ \hline
# EP300		& 10		& 3		& 8		& {\textbf{2}}		\\ \hline
# CTCF		& 10		& {\textbf{1}}		& {\textbf{1}}		& NA		\\ \hline
# MYC		& 10		& {\textbf{2}}		& 4		& NA		\\ \hline
# ETS		& 9		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# E2F		& 8		& {\textbf{1}}		& {\textbf{1}}		& 2.0		\\ \hline
# STAT		& 7		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# EGR1		& 7		& 2		& 2		& {\textbf{1}}		\\ \hline
# TCF12		& 6		& {\textbf{2}}		& 3		& {\textbf{2}}		\\ \hline
# NR3C1		& 6		& {\textbf{3}}		& 4		& {\textbf{3}}		\\ \hline
# IRF		& 6		& {\textbf{1}}		& 4		& 2.0		\\ \hline
# GATA		& 6		& {\textbf{3}}		& 4		& {\textbf{3}}		\\ \hline
# FOXA		& 5		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# HNF4		& 5		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# PAX5		& 5		& 3		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# YY1		& 5		& 4		& 4		& {\textbf{2}}		\\ \hline
# RXRA		& 5		& {\textbf{3}}		& 6		& {\textbf{3}}		\\ \hline
# NFE2		& 4		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# ZBTB33		& 4		& 3		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# SIX5		& 4		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# ATF3		& 4		& 4		& {\textbf{3}}		& {\textbf{3}}		\\ \hline
# NFKB		& 4		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# ZNF143		& 4		& 2		& 3		& {\textbf{1}}		\\ \hline
# NANOG		& 4		& 3		& 2		& {\textbf{1}}		\\ \hline
# ESRRA		& 4		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# PBX3		& 3		& 3		& 3		& {\textbf{1}}		\\ \hline
# BATF		& 3		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# SPI1		& 3		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# ELF1		& 3		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# RFX5		& 3		& 4		& 4		& {\textbf{2}}		\\ \hline
# SP1		& 3		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# MEF2		& 3		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# NRF1		& 3		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# NR2C2		& 3		& 3		& 3		& {\textbf{2}}		\\ \hline
# POU2F2		& {\textbf{2}}		& 4		& 3		& {\textbf{2}}		\\ \hline
# POU5F1		& 2		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# ZBTB7A		& 2		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# BHLHE40		& 2		& 2		& 3		& {\textbf{1}}		\\ \hline
# TFAP2		& 2		& 3		& 3		& {\textbf{1}}		\\ \hline
# TCF7L2		& {\textbf{2}}		& 4		& 4		& {\textbf{2}}		\\ \hline
# CEBPB		& 2		& {\textbf{1}}		& {\textbf{1}}		& 2.0		\\ \hline
# TAL1		& 2		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# EBF1		& 2		& 2		& 2		& {\textbf{1}}		\\ \hline
# SRF		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		& {\textbf{2}}		\\ \hline
# MXI1		& 2		& 4		& 4		& {\textbf{1}}		\\ \hline
# MAF		& 2		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# HEY1		& 2		& 2		& 2		& {\textbf{1}}		\\ \hline
# PRDM1		& 2		& 2		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# SREBP		& {\textbf{1}}		& {\textbf{1}}		& 2		& {\textbf{1}}		\\ \hline
# BRCA1		& {\textbf{1}}		& 4		& 11		& {\textbf{1}}		\\ \hline
# HSF		& {\textbf{1}}		& 2		& 3		& {\textbf{1}}		\\ \hline
# ZEB1		& {\textbf{1}}		& 2		& 4		& 2.0		\\ \hline
# NFY		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		& {\textbf{1}}		\\ \hline
# Winning Times 		& 8		& 33		& 24		& 46		\\ \hline
