# %%
import pandas as pd

# %%
def read_list(file):
	temp = []
	for line in open(file).readlines():
		line = line.strip().split()[0]
		temp.append(line)
	return temp

# %%
my_final_list = read_list("removed_sim_motifs.list")

# %%
my_final_list
# Out:
# ['DME_TTTKYTCTTTT',
#  'gimme_100_Improbizer_ACGAAAGAGAGAGAAAAG',
#  'DME_TYTATTTTATTT',
#  'DECOD_Motif3_16',
#  'gimme_20_BioProspector_w12_5',
#  'DECOD_Motif1_16',
#  'DME_TKYKYTTTCT',
#  'gimme_135_MEME_6_w10',
#  'DME_KAGRTYYKGM',
#  'gimme_153_MEME_4_w14',
#  'gimme_141_MEME_2_w12',
#  'DECOD_Motif1_14',
#  'DME_AGAAAAARRA']

# %%
my_final_list = read_list("motif_conservation_analysis.tsv")

# %%
df = pd.read_csv("HRGP_raw_both_strand.csv",index_col = 0)

# %%
df[my_final_list]
# Out:
#                                                     DME_KACAWRATTT  \
# AT3G57690|AT3G57690.1|AGP23|3|21384146|21384605                0.0
# AT2G18470|AT2G18470.3;AT2G18470.1;AT2G18470.2;A...             1.0
# AT4G33970|AT4G33970.1|PEX4|4|16278941|16282048                 1.0
# AT3G18810|AT3G18810.1|PERK6|3|6480484|6483774                  1.0
# AT3G01700|AT3G01700.1|AGP11|3|258879|259631                    1.0
# AT1G24520|AT1G24520.1|BCP1|1|8688563|8689268                   0.0
# AT1G23540|AT1G23540.1;AT1G23540.2|PERK12|1|8346...             1.0
# AT1G10620|AT1G10620.1|PERK11|1|3509001|3512321                 0.0
# AT1G49270|AT1G49270.1|PERK7|1|18227122|18230330                0.0
# AT4G34440|AT4G34440.2;AT4G34440.1|PERK5|4|16465...             1.0
# AT2G24450|AT2G24450.1|FLA3|2|10392787|10393976                 0.0
# AT1G54215|AT1G54215.1||1|20242878|20243730                     1.0
# AT5G14380|AT5G14380.1|AGP6|5|4635644|4636676                   1.0
# ...

# %%
# %matplotlib inline
	neg_series = data[data[label] == 0][m].tolist()
	pos_series = data[data[label] == 1][m].tolist()

# %%
df2 = pd.DataFrame(columns = ['fore','back'])
for c in df.columns[:-1]:
    df2.loc[c] = [df[df['class'] == 1][c].sum(),df[df['class'] == 0][c].sum()]

# %%
df2.loc[my_final_list]
# Out:
#                                          fore   back
# DME_TTTKYTCTTTT                          13.0  125.0
# gimme_100_Improbizer_ACGAAAGAGAGAGAAAAG  13.0   64.0
# DME_TYTATTTTATTT                         13.0  119.0
# DECOD_Motif3_16                          13.0   73.0
# gimme_20_BioProspector_w12_5             13.0   54.0
# DECOD_Motif1_16                          13.0  120.0
# DME_TKYKYTTTCT                           13.0  119.0
# gimme_135_MEME_6_w10                     13.0  123.0
# DME_KAGRTYYKGM                            9.0   33.0
# gimme_153_MEME_4_w14                     13.0  122.0
# gimme_141_MEME_2_w12                     13.0  118.0
# DECOD_Motif1_14                          13.0  107.0
# DME_AGAAAAARRA                           13.0  124.0

# %%
df2.shape
# Out:
# (3519, 2)

# %%
conserved = df2.loc[my_final_list]

# %%
final_result = conserved[conserved['back'] < 20][conserved['fore'] > 9]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
conserved[conserved['back'] <= 20][conserved['fore'] > 9]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                       fore  back
# DME_VASGSARAS         10.0  20.0
# DME_AHGGTGRWR         10.0  18.0
# DME_ARRTCYKVRG        10.0  16.0
# gimme_30_AMD_Motif5   10.0  19.0
# DME_RASWGAKCWA        10.0  20.0
# gimme_143_MEME_4_w12  11.0  16.0
# DECOD_Motif4_13       10.0  16.0
# DME_ACDGWGMYA         10.0  13.0

# %%
df2[df2['back'] < 20][df2['fore'] > 9].loc[my_final_list]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                              fore  back
# DME_GAGTAGCAGCAGCAGC                          NaN   NaN
# DME_GGAGATGGCGAG                              NaN   NaN
# gimme_34_AMD_Motif9                           NaN   NaN
# DME_KACAWRATTT                                NaN   NaN
# DME_TTYTCWKTWTG                               NaN   NaN
# DME_GGATGAGCAGCGACCA                          NaN   NaN
# DME_GAGGGGGAGGAAG                             NaN   NaN
# DME_GATYYGCT                                  NaN   NaN
# DME_TTTTATTTRKTT                              NaN   NaN
# DME_TGAGCTACGAG                               NaN   NaN
# DME_RARSRAGASHG                               NaN   NaN
# DME_CGATGGGTCGGCTT                            NaN   NaN
# ...

# %%
import seaborn as sns
lm = sns.regplot(x="fore", y="back", data=df2, fit_reg=False)
lm.set(ylim=(-1, None),xlim=(-1, 14))
# Out:
# [(-1, 140.0), (-1, 14)]
