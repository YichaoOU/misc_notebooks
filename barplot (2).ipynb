# %%
import pandas as pd

# %%
df = pd.read_csv("../counting.result.csv",index_col=0)

# %%
df
# Out:
#       chr18   chr16    chr2    chr7   chr15   chr17   chr11    chr5  chr19  \
# 0.1  239996  311743  923588  652901  322135  271362  497105  661578  79434
# 0.2  163950  195252  535761  338064  234178  165769  267365  383760  67686
# 0.3   31584   37741   85302   57809   44635   31117   47644   60922  14353
# 0.4    6837    7552   16602   12222    8501    6580   10062   10826   3946
# 0.5    2006    2100    4858    3824    2345    1906    3117    3037   1420
# 0.6     732     760    1781    1427     809     687    1082    1152    536
# 0.7     275     281     742     500     335     252     377     411    221
# 0.8     110     111     307     196     107      92     119     171     83
# 0.9      37      39     119      83      44      25      43      76     39
#
#       chr14     chr1   chr13   chr12    chr6    chr8    chr4    chr3   chr10  \
# 0.1  471313  1146070  315492  458764  702146  505659  717811  866912  450145
# ...

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
for i in df.index.tolist():
    f, axs = plt.subplots(figsize=(15,5))
    plt.bar(np.arange(19),df.loc[i])
    plt.xticks(np.arange(19)+0.4, df.columns.tolist())
    plt.title("Number of interaction at given threshold:"+str(i))
    plt.savefig("Prob"+str(i)+".png")

# %%
# Out:
# ['chr18',
#  'chr16',
#  'chr2',
#  'chr7',
#  'chr15',
#  'chr17',
#  'chr11',
#  'chr5',
#  'chr19',
#  'chr14',
#  'chr1',
#  'chr13',
#  'chr12',
#  'chr6',
#  'chr8',
#  'chr4',
#  'chr3',
#  'chr10',
#  'chr9']

# %%
# Out:
# chr18     239996
# chr16     311743
# chr2      923588
# chr7      652901
# chr15     322135
# chr17     271362
# chr11     497105
# chr5      661578
# chr19      79434
# chr14     471313
# chr1     1146070
# chr13     315492
# chr12     458764
# chr6      702146
# chr8      505659
# chr4      717811
# chr3      866912
# chr10     450145
# chr9      439792
# Name: 0.1, dtype: int64
