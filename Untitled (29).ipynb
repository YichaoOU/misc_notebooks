# %%
import pandas as pd
motif_df = pd.read_csv('../window_loci_motif_enrichment/GAM.HoxB.window.differences.csv',index_col=0)

# %%
loci_motif_csv = pd.read_csv("/home/working/my_second_drive/projects/GAM_motif_analysis/GAM_motif_features.csv",index_col=0)

# %%
loci_motif_csv_dict = {}
for x in loci_motif_csv.index:
	loci_motif_csv_dict[x] = loci_motif_csv.loc[x]

# %%
loci_motif_csv.head()
# Out:
#                       BARX1_MOUSE.H11MO.0.C  IRF8_MOUSE.H11MO.0.A  \
# name
# chr1:3000000-3030000                    165                   659
# chr1:3030000-3060000                     88                   380
# chr1:3060000-3090000                     88                   513
# chr1:3090000-3120000                    121                   789
# chr1:3120000-3150000                    154                   544
#
#                       COT1_MOUSE.H11MO.0.B  RXRA_MOUSE.H11MO.0.A  \
# name
# chr1:3000000-3030000                    72                   200
# chr1:3030000-3060000                    87                   220
# chr1:3060000-3090000                    40                   120
# chr1:3090000-3120000                    40                   220
# chr1:3120000-3150000                    48                   180
#
#                       ETV6_MOUSE.H11MO.0.C  MTF1_MOUSE.H11MO.0.C  \
# name
# chr1:3000000-3030000                   192                    96
# ...

# %%
loci_motif_csv_dict['chr1:3000000-3030000']['BARX1_MOUSE.H11MO.0.C']
# Out:
# 165

# %%
motif_df.to_dict()
# Out:
# {'BackCov': {0: 0.99843408232300002,
#   1: 0.99992543249200005,
#   2: 0.99972658580200002,
#   3: 0.99992543249200005,
#   4: 1.0,
#   5: 0.93065221714099999,
#   6: 0.99980115331100006,
#   7: 0.9971664346789999,
#   8: 0.99995028832800004,
#   9: 0.999751441638,
#   10: 0.99724100218700007,
#   11: 0.99972658580200002,
#   12: 0.99992543249200005,
#   13: 0.85054185722800002,
#   14: 0.61980513024499995,
#   15: 0.9988317757009999,
#   16: 0.99870749652000013,
#   17: 0.998732352356,
#   18: 0.998086100616,
#   19: 0.99952773911300008,
#   20: 0.98836746868200009,
#   21: 0.99763869556600004,
#   22: 0.99609763372399995,
#   23: 1.0,
#   24: 0.9980612447799998,
#   25: 0.99995028832800004,
#   26: 0.98217836547999993,
#   27: 0.99336349174799998,
#   28: 0.99050507059100001,
#   29: 0.98431596738900007,
#   30: 0.99830980314200002,
#   31: 0.99940345993200008,
#   32: 0.9992543249150001,
#   33: 0.9988317757009999,
#   34: 0.99965201829400008,
#   35: 0.99318950089499991,
# ...

# %%
motif_df['diff'] = motif_df.ForeCov - motif_df.BackCov

# %%
motif_df
# Out:
#                      Motif  ForeCov   BackCov      diff
# 0    BARX1_MOUSE.H11MO.0.C     1.00  0.998434  0.001566
# 1     IRF8_MOUSE.H11MO.0.A     1.00  0.999925  0.000075
# 2     COT1_MOUSE.H11MO.0.B     1.00  0.999727  0.000273
# 3     RXRA_MOUSE.H11MO.0.A     1.00  0.999925  0.000075
# 4     ETV6_MOUSE.H11MO.0.C     1.00  1.000000  0.000000
# 5     MTF1_MOUSE.H11MO.0.C     1.00  0.930652  0.069348
# 6     NDF2_MOUSE.H11MO.0.A     1.00  0.999801  0.000199
# 7    FOSL2_MOUSE.H11MO.0.A     1.00  0.997166  0.002834
# 8    HNF4G_MOUSE.H11MO.0.C     1.00  0.999950  0.000050
# 9     MAFF_MOUSE.H11MO.0.A     1.00  0.999751  0.000249
# 10   ARI5B_MOUSE.H11MO.0.C     1.00  0.997241  0.002759
# 11    IRF7_MOUSE.H11MO.0.C     1.00  0.999727  0.000273
# 12    EGR2_MOUSE.H11MO.0.A     1.00  0.999925  0.000075
# 13    MYCN_MOUSE.H11MO.0.A     0.95  0.850542  0.099458
# 14    MBD2_MOUSE.H11MO.0.B     0.95  0.619805  0.330195
# 15   PO3F1_MOUSE.H11MO.0.C     1.00  0.998832  0.001168
# ...

# %%
motif_df['diff'] >= 0.05
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# 334    False
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# 344    False
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# 350    False
# 351    False
# 352    False
# 353    False
# 354    False
# 355    False
# 356    False
# 357    False
# Name: diff, Length: 358, dtype: bool
