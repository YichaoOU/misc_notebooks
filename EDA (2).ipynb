# %%
import pandas as pd

# %%
pos = pd.read_csv("SLICE_08_pos.csv",index_col = 0)
neg = pd.read_csv("background.csv",index_col = 0)

# %%
pos['color'] = [(0.86, 0.37119999999999997, 0.33999999999999997)]*pos.shape[0]

# %%
neg['color'] = [(0.56880000000000008, 0.86, 0.33999999999999997)]*neg.shape[0]

# %%
df = pd.concat([pos,neg])

# %%
df.head()
# Out:
#                       CHD2.ES-E14.ENCFF466DTV  H3K36me3.E14TG2a.4.ENCFF759WKW  \
# chr1:4140000-4170000                        0                               0
# chr1:4320000-4350000                        0                               0
# chr1:4350000-4380000                        0                               0
# chr1:4380000-4410000                        0                               0
# chr1:5820000-5850000                        0                               0
#
#                       H3K9me3.ES-E14.ENCFF090UKL  DNase.WW6.ENCFF971CGW  \
# chr1:4140000-4170000                           0                      1
# chr1:4320000-4350000                           0                      1
# chr1:4350000-4380000                           0                      0
# chr1:4380000-4410000                           0                      1
# chr1:5820000-5850000                           0                      0
#
#                       H3K4me1.ES-Bruce4.ENCFF333IJH  \
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.clustermap(df[df.columns[:-1]],standard_scale=1,method="ward",figsize=(15,15),row_colors = df[df.columns[-1]],row_cluster=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-f762fde0387d> in <module>()
# ----> 1 sns.clustermap(df[df.columns[:-1]],standard_scale=1,method="average",figsize=(15,15))
#
# /usr/local/lib/python2.7/dist-packages/seaborn/matrix.pyc in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, **kwargs)
#    1299                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1300                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1301                         **kwargs)
#
# /usr/local/lib/python2.7/dist-packages/seaborn/matrix.pyc in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, **kws)
#    1129         colorbar_kws = {} if colorbar_kws is None else colorbar_kws
# ...

# %%
sns.clustermap(pos[pos.columns[:-1]].corr(),figsize=(15,15),cmap="RdBu_r")

# %%
pos = pd.read_csv("SLICE_08_pos.csv",index_col = 0)
neg = pd.read_csv("background.csv",index_col = 0)
pos['class'] = [1]*pos.shape[0]
neg['class'] = [0]*neg.shape[0]
df = pd.concat([pos,neg])
df = df/df.max()
column_list = df.columns.tolist()
class_1 = pd.melt(df[df['class'] == 1],value_vars=column_list[:-1])
class_1['class'] = "pos"
class_1.head()
class_2 = pd.melt(df[df['class'] == 0],value_vars=column_list[:-1])
class_2['class'] = "neg"
class_2.head()
# Out:
#                   variable  value class
# 0  CHD2.ES-E14.ENCFF466DTV    0.0   neg
# 1  CHD2.ES-E14.ENCFF466DTV    0.0   neg
# 2  CHD2.ES-E14.ENCFF466DTV    0.0   neg
# 3  CHD2.ES-E14.ENCFF466DTV    0.0   neg
# 4  CHD2.ES-E14.ENCFF466DTV    0.0   neg

# %%
plot_data = pd.concat([class_1,class_2])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
f, ax = plt.subplots(figsize=(12, 70))
sns.set(font_scale=1.5)
sns.boxplot(x="value",y="variable",hue="class",data=plot_data,palette=sns.hls_palette(2))

# %%
pos['chen2008-NANOG.fimo'].describe()
# Out:
# count    5649.000000
# mean       12.785449
# std         4.173893
# min         1.000000
# 25%        10.000000
# 50%        13.000000
# 75%        15.000000
# max        46.000000
# Name: chen2008-NANOG.fimo, dtype: float64

# %%
neg['chen2008-NANOG.fimo'].describe()
# Out:
# count    5649.000000
# mean       12.346433
# std         4.585299
# min         0.000000
# 25%        10.000000
# 50%        12.000000
# 75%        15.000000
# max        36.000000
# Name: chen2008-NANOG.fimo, dtype: float64

# %%
neg
# Out:
#                           HCFC1.ES-E14.ENCFF030DBG  chen2008-NANOG.fimo  \
# chr1:1080000-1110000                             0                    0
# chr1:1590000-1620000                             0                    0
# chr1:1830000-1860000                             0                    0
# chr1:2130000-2160000                             0                    0
# chr1:2250000-2280000                             0                    0
# chr1:2670000-2700000                             0                    0
# chr1:3060000-3090000                             0                   22
# chr1:3210000-3240000                             0                   18
# chr1:3300000-3330000                             0                   16
# chr1:3330000-3360000                             0                   14
# chr1:3420000-3450000                             0                   21
# chr1:4050000-4080000                             0                   18
# ...

# %%
import pandas as pd
pos = pd.read_csv("SLICE_08_pos.csv",index_col = 0)
neg = pd.read_csv("SLICE_08_neg.csv",index_col = 0)
pos['class'] = [1]*pos.shape[0]
neg['class'] = [0]*neg.shape[0]
df = pd.concat([pos,neg])

# %%
df.head()
# Out:
#                       CHD2.ES-E14.ENCFF466DTV  CTCF.E14TG2a.4.ENCFF969YUQ  \
# chr1:4140000-4170000                        0                           0
# chr1:4320000-4350000                        0                           2
# chr1:4350000-4380000                        0                           0
# chr1:4380000-4410000                        0                           1
# chr1:5820000-5850000                        0                           0
#
#                       CTCF.ES-Bruce4.ENCFF926DQD  DNase.ES-E14.ENCFF167GZG  \
# chr1:4140000-4170000                           0                         3
# chr1:4320000-4350000                           1                         2
# chr1:4350000-4380000                           0                         1
# chr1:4380000-4410000                           1                         1
# chr1:5820000-5850000                           0                         0
#
# ...

# %%
from sklearn import manifold, datasets
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def PCA_2d_plot(new_X,Y):
	colors =['red','green']
	plt.figure()
	for color, i, target_name in zip(colors, [0,1], ['neg','pos']):
	    plt.scatter(new_X[Y == i, 0], new_X[Y == i, 1], color=color, alpha=.4, lw=1,
	                label=target_name)
	plt.legend(loc='best', shadow=False, scatterpoints=1)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
my_new_data = pca.fit_transform(df[df.columns[:-1]])
PCA_2d_plot(my_new_data,Y=df[df.columns[-1]])

# %%
from mlxtend.classifier import StackingCVClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier,LogisticRegression,RidgeClassifier
from sklearn.ense 
meta_r = LogisticRegression()
stacker = StackingCVClassifier(classifiers = [r1,r2,r3,r4,r2_1,r2_2,r4_1,rx],meta_classifier = meta_r, cv=3)
stacker.fit(X_train,y_train)
# Out:
# StackingCVClassifier(classifiers=[KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'), RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, ran...:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)],
#            cv=3,
#            meta_classifier=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#            shuffle=True, stratify=True, use_features_in_secondary=False,
#            use_probas=False, verbose=0)

# %%
y_pred = stacker.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.53496017195599954
