# %%
import numpy as np
import gc
from joblib import Parallel, delayed
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
data = np.load('1MNet.npy')
print data.sum()
import pandas as pd
genes = map(lambda x:x.strip().split()[0],open("Genes.txt").readlines())
len(genes)
df = pd.DataFrame(data,dtype=np.float64)
df.index = genes
df.columns = genes
del data
gc.collect()
df.head()

df_new = df.loc[(df != 0).any(axis=1), (df != 0).any(axis=0)]
# Out:
# 2000000

# %%
from mcl_clustering import mcl

# %%
M,clusters = mcl(df_new.values,inflate_factor=6,expand_factor =5)
print len(clusters)
# Out:
# 475

# %%
for x in clusters:
    print len(clusters[x])
# Out:
# 2
# 3
# 2
# 28
# 3
# 3
# 7
# 6
# 10
# 3
# 9
# 9
# 3
# 3
# 2
# 2
# 2
# 9
# 2
# 2
# 11
# 8
# 2
# 4
# 2
# 8
# 9
# 6
# 8
# 6
# 108
# 10
# 5
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 4
# 2
# 3
# 2
# 2
# 2
# 3
# 11
# 4
# 2
# 4
# 2
# 2
# 978
# 3
# 3
# 8
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 1063
# 2
# 2
# 9
# 3
# 6
# 2
# 2
# 3
# 5
# 5
# 2
# 2
# 3
# 5
# 3
# 2
# 12
# 2
# 10
# 2
# 2
# 2
# 9
# 5
# 3
# 13
# 2
# 2
# 2
# 6
# 2
# 8
# 4
# 4
# 5
# 3
# 5
# 2
# 3
# 5
# 4
# 6
# 3
# 3
# 2
# 2
# 2
# 2
# 7
# 2
# 2
# 3
# 2
# 2
# 2
# 10
# 3
# 2
# 2
# 2
# 2
# 2
# 7
# 6
# 2
# 2
# 10
# 30
# 2
# 2
# 5
# 2
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 10
# 6
# 2
# 3
# 2
# 9
# 2
# 2
# 2
# 29
# 7
# 2
# 8
# 2
# 3
# 5
# 2
# 3
# 2
# 2
# 2
# 5
# 4
# 7
# 6
# 2
# 2
# 16
# 3
# 4
# 2
# 2
# 21
# 11
# 2
# 5
# 7
# 2
# 2
# 8
# 2
# 7
# 2
# 3
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 42
# 2
# 2
# 2
# 2
# 2
# 4
# 4
# 4
# 5159
# 6
# 2
# 2
# 3
# 2
# 7
# 2
# 2
# 3
# 2
# 4
# 6
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 68
# 2
# 16
# 2
# 2
# 145
# 3
# 2
# 2
# 2
# 2
# 2
# 5
# 2
# ...

# %%
M,clusters = mcl(df_new.values,inflate_factor=10)
print len(clusters)
# Out:
# 4860

# %%
# df_new.sample(n=30).sum()
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import LinearSegmentedColormap
# sns.set(color_codes=True)
# sns.set(font_scale=0.5)
my_df = pd.DataFrame()
my_df["a"] = [0,0,0]
my_df["b"] = [0,1,0]
my_df["c"] = [0,0,0]
my_df.shape
myColors = ((.77, .89, .77, 1.0),(0.0, 0.1, 0.1, 1.0))
cmap = LinearSegmentedColormap.from_list('Custom', myColors, len(myColors))
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
# plot = sns.clustermap(df_new.sample(n=500), row_cluster=True,standard_scale =0,figsize=(15,15))
# sns.palplot(sns.dark_palette((260, 75, 60), input="husl"))
ax=sns.clustermap(my_df,cmap = cmap)
# plt.setp(plot.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
# plot.savefig("heatmap.png",dpi=1000)
# Manually specify colorbar labelling after it's been generated

# %%
sns.clustermap(df_new.astype(int),row_cluster=False, col_cluster=False)

# %%
df_new.astype(int).sum()
# Out:
# HORVU0Hr1G000080       7
# HORVU0Hr1G000280     352
# HORVU0Hr1G000320     233
# HORVU0Hr1G000390      98
# HORVU0Hr1G000410     175
# HORVU0Hr1G000510      10
# HORVU0Hr1G000600     127
# HORVU0Hr1G000710       3
# HORVU0Hr1G001240      12
# HORVU0Hr1G001270     198
# HORVU0Hr1G001280       1
# HORVU0Hr1G001340     284
# HORVU0Hr1G001390       1
# HORVU0Hr1G001400     141
# HORVU0Hr1G001440       2
# HORVU0Hr1G001450     233
# HORVU0Hr1G001460      53
# HORVU0Hr1G001490     331
# HORVU0Hr1G001510      24
# HORVU0Hr1G001530     339
# HORVU0Hr1G001570       6
# HORVU0Hr1G002090      63
# HORVU0Hr1G002300     475
# HORVU0Hr1G002340       1
# HORVU0Hr1G002480       2
# HORVU0Hr1G002530       1
# HORVU0Hr1G002680     635
# HORVU0Hr1G002690     261
# HORVU0Hr1G002960     217
# HORVU0Hr1G003010       3
#                     ...
# HORVU7Hr1G119520     175
# HORVU7Hr1G119590     125
# HORVU7Hr1G119620       1
# HORVU7Hr1G119680     369
# HORVU7Hr1G119700     244
# HORVU7Hr1G119810     747
# ...

# %%
new_df = df_new.sample(n=3)[df_new.columns[:3]]
new_df.shape
# Out:
# (3, 3)

# %%
new_df=new_df.astype(int)

# %%
my_df
# Out:
#    a  b  c
# 0  0  0  0
# 1  0  0  0
# 2  0  0  0
