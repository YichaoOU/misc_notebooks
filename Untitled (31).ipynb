# %%
import pandas as pd
df = pd.read_csv("HRGP_raw_both_strand.csv",index_col=0)

# %%
df[df[df.columns[-1]] == 1]
# Out:
#                                                     gimme_15_BioProspector_w10_5  \
# AT3G57690|AT3G57690.1|AGP23|3|21384146|21384605                              1.0
# AT2G18470|AT2G18470.3;AT2G18470.1;AT2G18470.2;A...                           0.0
# AT4G33970|AT4G33970.1|PEX4|4|16278941|16282048                               1.0
# AT3G18810|AT3G18810.1|PERK6|3|6480484|6483774                                1.0
# AT3G01700|AT3G01700.1|AGP11|3|258879|259631                                  1.0
# AT1G24520|AT1G24520.1|BCP1|1|8688563|8689268                                 0.0
# AT1G23540|AT1G23540.1;AT1G23540.2|PERK12|1|8346...                           0.0
# AT1G10620|AT1G10620.1|PERK11|1|3509001|3512321                               1.0
# AT1G49270|AT1G49270.1|PERK7|1|18227122|18230330                              1.0
# AT4G34440|AT4G34440.2;AT4G34440.1|PERK5|4|16465...                           1.0
# AT2G24450|AT2G24450.1|FLA3|2|10392787|10393976                               1.0
# ...

# %%
features = ["gimme_41_Homer_8_2","gimme_43_Homer_8_4","gimme_42_Homer_8_3","DME_TCACCGGGGAGAAG","DME_CTGSRRGWW","DME_CGAGAGCTGCTTGC"]
features = ["gimme_34_AMD_Motif9","DME_TARTAAGVS","DME_SWGWGCTA","DME_RCRDTGSAA","DME_MGGRYYTYG","DME_BACKGWGA"]
for i in features:
    pos_number = df[df[df.columns[-1]] == 1][i].sum()
    neg_number = df[df[df.columns[-1]] == 0][i].sum()

    print i,pos_number,neg_number,(pos_number/13.0)/(neg_number/132.0)
# Out:
# gimme_34_AMD_Motif9 8.0 12.0 6.76923076923
# DME_TARTAAGVS 8.0 14.0 5.8021978022
# DME_SWGWGCTA 8.0 8.0 10.1538461538
# DME_RCRDTGSAA 9.0 14.0 6.52747252747
# DME_MGGRYYTYG 8.0 10.0 8.12307692308
# DME_BACKGWGA 8.0 9.0 9.02564102564
