# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_csv("Mouse_Hist1_interaction_features.csv")

# %%
df.head()
# Out:
#                       name                 variable     value  distance  \
# 0  chr13:23880000-23910000  chr13:24240000-24270000  0.942272      12.0
# 1  chr13:23880000-23910000  chr13:24210000-24240000  0.929070      11.0
# 2  chr13:24090000-24120000  chr13:24210000-24240000  0.916813       4.0
# 3  chr13:24000000-24030000  chr13:24360000-24390000  0.897877      12.0
# 4  chr13:23100000-23130000  chr13:23160000-23190000  0.863976       2.0
#
#    R1-EP300.ES-Bruce4.ENCFF350GCX  R2-EP300.ES-Bruce4.ENCFF350GCX  \
# 0                               0                               0
# 1                               0                               0
# 2                             284                               0
# 3                               0                               0
# 4                              95                               0
#
#    R1-H3K36me3.ES-E14.ENCFF556TVG  R2-H3K36me3.ES-E14.ENCFF556TVG  \
# 0                               0                             156
# 1                               0                             501
# 2                             314                             501
# 3                               0                             396
# 4                               0                               0
#
#    R1-H3K9ac.ES-E14.ENCFF487JDK  R2-H3K9ac.ES-E14.ENCFF487JDK  \
# 0                             0                             0
# 1                             0                             0
# 2                            41                             0
# 3                             0                          1880
# 4                             0                             0
#
#             ...             R1-chen2008-NANOG.fimo  R2-chen2008-NANOG.fimo  \
# 0           ...                                270                     135
# 1           ...                                270                     165
# 2           ...                                240                     165
# 3           ...                                120                      75
# 4           ...                                255                     255
#
#    R1-Up-Genes  R2-Up-Genes  R1-Down-Genes             R2-Down-Genes  \
# 0          NaN          NaN            NaN                       NaN
# 1          NaN          NaN            NaN                       NaN
# 2         Scgn          NaN            NaN                       NaN
# 3          NaN          NaN            NaN                       NaN
# 4          NaN          NaN            NaN  Vmn1r216,Gm11325,Gm11326
#
#                          R1-Overlap-Genes  R2-Overlap-Genes  \
# 0                  Trim38,Gm11337,Slc17a2           Lrrc16a
# 1                  Trim38,Gm11337,Slc17a2           Lrrc16a
# 2                                 Lrrc16a           Lrrc16a
# 3  Slc17a4,Snrp1c-ps2,Hist1h2ba,Hist1h2aa   Lrrc16a,Gm11340
# 4               Vmn1r213,Gm11323,Vmn1r214          Vmn1r215
#
#            R1-Overlap-TADs          R2-Overlap-TADs
# 0  chr13:23840000-25040000  chr13:23840000-25040000
# 1  chr13:23840000-25040000  chr13:23840000-25040000
# 2  chr13:23840000-25040000  chr13:23840000-25040000
# 3  chr13:23840000-25040000  chr13:23840000-25040000
# 4  chr13:22200000-23720000  chr13:22200000-23720000
#
# [5 rows x 130 columns]

# %%
selected_nodes = df.name.tolist() + df.variable.tolist()
selected_nodes = list(set(selected_nodes))

# %%
G=nx.from_pandas_edgelist(df, 'name', 'variable', edge_attr=['value','distance'])

# %%
G['chr13:23880000-23910000']['chr13:24240000-24270000']
# Out:
# {'distance': 12.0, 'value': 0.942272}

# %%
nodes = pd.read_csv("Mouse_loci_features.csv",index_col=0)

# %%
nodes.head()
# Out:
#                          EP300.ES-Bruce4.ENCFF350GCX  \
# name
# chr13:23280000-23310000                            0
# chr13:23130000-23160000                            0
# chr13:23100000-23130000                           95
# chr13:23370000-23400000                          284
# chr13:21780000-21810000                          284
#
#                          H3K36me3.ES-E14.ENCFF556TVG  \
# name
# chr13:23280000-23310000                            0
# chr13:23130000-23160000                            0
# chr13:23100000-23130000                            0
# chr13:23370000-23400000                            0
# chr13:21780000-21810000                            0
#
#                          H3K9ac.ES-E14.ENCFF487JDK  chen2008-KLF4.fimo  \
# name
# chr13:23280000-23310000                          0                  72
# chr13:23130000-23160000                          0                 131
# chr13:23100000-23130000                          0                 132
# chr13:23370000-23400000                       2835                  99
# chr13:21780000-21810000                       2042                  54
#
#                          H3K4me1.ES-E14.ENCFF067VMS  chen2008-ESRRB.fimo  \
# name
# chr13:23280000-23310000                           0                  154
# chr13:23130000-23160000                           0                   99
# chr13:23100000-23130000                         181                   88
# chr13:23370000-23400000                         315                  121
# chr13:21780000-21810000                           0                  132
#
#                          MAFK.ES-E14.ENCFF535CTU  \
# name
# chr13:23280000-23310000                        0
# chr13:23130000-23160000                        0
# chr13:23100000-23130000                        0
# chr13:23370000-23400000                     1184
# chr13:21780000-21810000                      616
#
#                          H3K9ac.ES-Bruce4.ENCFF290XDT  \
# name
# chr13:23280000-23310000                             0
# chr13:23130000-23160000                             0
# chr13:23100000-23130000                             0
# chr13:23370000-23400000                          4088
# chr13:21780000-21810000                          2916
#
#                          H3K27ac.ES-Bruce4.ENCFF360VIS  \
# name
# chr13:23280000-23310000                              0
# chr13:23130000-23160000                              0
# chr13:23100000-23130000                            832
# chr13:23370000-23400000                           1984
# chr13:21780000-21810000                           2353
#
#                          ZC3H11A.ES-E14.ENCFF024QSW           ...             \
# name                                                          ...
# chr13:23280000-23310000                           0           ...
# chr13:23130000-23160000                         256           ...
# chr13:23100000-23130000                           0           ...
# chr13:23370000-23400000                           0           ...
# chr13:21780000-21810000                           0           ...
#
#                          H3K27me3.ES-Bruce4.ENCFF558YNC  \
# name
# chr13:23280000-23310000                               0
# chr13:23130000-23160000                               0
# chr13:23100000-23130000                               0
# chr13:23370000-23400000                               0
# chr13:21780000-21810000                               0
#
#                          H3K36me3.ES-Bruce4.ENCFF299BTW  \
# name
# chr13:23280000-23310000                               0
# chr13:23130000-23160000                               0
# chr13:23100000-23130000                               0
# chr13:23370000-23400000                               0
# chr13:21780000-21810000                               0
#
#                          H3K27ac.ES-E14.ENCFF194TQD  \
# name
# chr13:23280000-23310000                           0
# chr13:23130000-23160000                           0
# chr13:23100000-23130000                         405
# chr13:23370000-23400000                           0
# chr13:21780000-21810000                        1702
#
#                          H3K9me3.ES-E14.ENCFF090UKL  DNase.ES-E14.ENCFF911LAE  \
# name
# chr13:23280000-23310000                         214                         0
# chr13:23130000-23160000                           0                         0
# chr13:23100000-23130000                         515                       450
# chr13:23370000-23400000                           0                      1520
# chr13:21780000-21810000                           0                       620
#
#                          chen2008-NANOG.fimo  Up-Genes           Down-Genes  \
# name
# chr13:23280000-23310000                  315  Vmn1r220                  NaN
# chr13:23130000-23160000                  255  Vmn1r214             Vmn1r215
# chr13:23100000-23130000                  255       NaN                  NaN
# chr13:23370000-23400000                  195   Gm11332        4930586N03Rik
# chr13:21780000-21810000                  180       NaN  Hist1h2aj,Hist1h2bm
#
#                                                  Overlap-Genes  \
# name
# chr13:23280000-23310000                        Gm11328,Gm11329
# chr13:23130000-23160000                                Gm11327
# chr13:23100000-23130000              Vmn1r213,Gm11323,Vmn1r214
# chr13:23370000-23400000    4930557F10Rik,4933404K08Rik,Gm11333
# chr13:21780000-21810000  Olfr1359,Hist1h2bl,Hist1h2ai,Hist1h3h
#
#                                     Overlap-TADs
# name
# chr13:23280000-23310000  chr13:22200000-23720000
# chr13:23130000-23160000  chr13:22200000-23720000
# chr13:23100000-23130000  chr13:22200000-23720000
# chr13:23370000-23400000  chr13:22200000-23720000
# chr13:21780000-21810000  chr13:20400000-21920000
#
# [5 rows x 63 columns]

# %%
nodes = nodes.fillna("")

# %%
pd.Series(nodes[c], index=["chr13:23280000-23310000"])
# Out:
# chr13:23280000-23310000    chr13:22200000-23720000
# Name: Overlap-TADs, dtype: object

# %%
for c in nodes.columns:
    nx.set_node_attributes(G, pd.Series(nodes[c], index=selected_nodes).to_dict(), c.replace(".","").replace("-",""))

# %%
G.node['chr13:23880000-23910000']
# Out:
# {'CHD2ESE14ENCFF466DTV': 0,
#  'CTCFE14TG2a4ENCFF969YUQ': 165,
#  'CTCFESBruce4ENCFF926DQD': 200,
#  'DNaseESE14ENCFF167GZG': 150,
#  'DNaseESE14ENCFF797POV': 0,
#  'DNaseESE14ENCFF809UQX': 150,
#  'DNaseESE14ENCFF911LAE': 0,
#  'DNaseWW6ENCFF038FMN': 0,
#  'DNaseWW6ENCFF227YIF': 0,
#  'DNaseWW6ENCFF448HUO': 0,
#  'DNaseWW6ENCFF594LCV': 300,
#  'DNaseWW6ENCFF651VVB': 150,
#  'DNaseWW6ENCFF673WPS': 0,
#  'DNaseWW6ENCFF971CGW': 0,
#  'DNaseWW6ENCFF994GNO': 0,
#  'DNaseZHBTc4mESCENCFF082FXK': 300,
#  'DNaseZHBTc4mESCENCFF096WRW': 0,
#  'DNaseZHBTc4mESCENCFF111WVB': 0,
#  'DNaseZHBTc4mESCENCFF485JVJ': 300,
#  'DownGenes': '',
#  'EP300ESBruce4ENCFF350GCX': 0,
#  'H3K27acESBruce4ENCFF360VIS': 0,
#  'H3K27acESE14ENCFF194TQD': 0,
#  'H3K27me3E14TG2a4ENCFF988MSF': 1527,
#  'H3K27me3ESBruce4ENCFF558YNC': 0,
#  'H3K36me3E14TG2a4ENCFF759WKW': 0,
#  'H3K36me3ESBruce4ENCFF299BTW': 0,
#  'H3K36me3ESE14ENCFF556TVG': 0,
#  'H3K4me1E14TG2a4ENCFF763GNF': 0,
#  'H3K4me1ESBruce4ENCFF333IJH': 0,
#  'H3K4me1ESE14ENCFF067VMS': 0,
#  'H3K4me1ESE14ENCFF440FYE': 0,
#  'H3K4me3E14TG2a4ENCFF406BED': 0,
#  'H3K4me3ESBruce4ENCFF247GVM': 0,
#  'H3K4me3ESE14ENCFF012AZO': 0,
#  'H3K4me3ESE14ENCFF680CYO': 0,
#  'H3K9acESBruce4ENCFF290XDT': 0,
#  'H3K9acESE14ENCFF487JDK': 0,
#  'H3K9me3E14TG2a4ENCFF180LQA': 0,
#  'H3K9me3ESBruce4ENCFF834MWI': 466,
#  'H3K9me3ESE14ENCFF090UKL': 0,
#  'HCFC1ESE14ENCFF030DBG': 0,
#  'MAFKESE14ENCFF535CTU': 0,
#  'NANOGE14TG2a4ENCFF557KRT': 0,
#  'OverlapGenes': 'Trim38,Gm11337,Slc17a2',
#  'OverlapTADs': 'chr13:23840000-25040000',
#  'POLR2AESBruce4ENCFF860MNF': 0,
#  'POU5F1E14TG2a4ENCFF499ROE': 0,
#  'UpGenes': '',
#  'ZC3H11AESE14ENCFF024QSW': 256,
#  'ZNF384ESE14ENCFF960DFA': 350,
#  'chen2008CMYCfimo': 18,
#  'chen2008CTCFfimo': 270,
#  'chen2008ESRRBfimo': 165,
#  'chen2008KLF4fimo': 81,
#  'chen2008NANOGfimo': 270,
#  'chen2008NMYCfimo': 18,
#  'chen2008OCT4fimo': 112,
#  'chen2008SMAD1fimo': 315,
#  'chen2008SOX2fimo': 182,
#  'chen2008STAT3fimo': 92,
#  'chen2008TCFCP2I1fimo': 91,
#  'chen2008ZFXfimo': 22}

# %%
nx.write_gml(G, 'Mouse_Hist1.gml')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx.draw(G)
