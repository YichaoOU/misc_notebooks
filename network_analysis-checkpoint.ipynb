# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_csv("Mouse_Hist1_fitHic_interaction_features.csv")

# %%
df.head()
# Out:
#                       name                 variable         value   distance  \
# 0  chr13:23390749-23430749  chr13:23442486-23482486  2.296937e-28   1.293425
# 1  chr13:22949670-22989670  chr13:23353920-23393920  4.644307e-07  10.106250
# 2  chr13:23515080-23555080  chr13:23640433-23680433  7.143810e-11   3.133825
# 3  chr13:22098557-22138557  chr13:23353920-23393920  9.713569e-13  31.384075
# 4  chr13:22017228-22057228  chr13:23640433-23680433  6.728655e-11  40.580125
#
#    R1-ZNF384.ES-E14.ENCFF960DFA  R2-ZNF384.ES-E14.ENCFF960DFA  \
# 0                           106                             0
# 1                           152                           456
# 2                          1699                          1399
# 3                          1773                           456
# 4                          1201                          1399
#
#    R1-H3K4me1.ES-E14.ENCFF440FYE  R2-H3K4me1.ES-E14.ENCFF440FYE  \
# 0                              0                              0
# 1                              0                              0
# 2                            302                              0
# 3                            163                              0
# 4                              0                              0
#
#    R1-H3K36me3.E14TG2a.4.ENCFF759WKW  R2-H3K36me3.E14TG2a.4.ENCFF759WKW  \
# 0                                  0                              13295
# 1                                  0                                  0
# 2                                  0                                  0
# 3                                531                                  0
# 4                               8812                                  0
#
#             ...             R1-POLR2A.ES-Bruce4.ENCFF860MNF  \
# 0           ...                                           0
# 1           ...                                           0
# 2           ...                                           0
# 3           ...                                         735
# 4           ...                                           0
#
#    R2-POLR2A.ES-Bruce4.ENCFF860MNF  R1-Up-Genes         R2-Up-Genes  \
# 0                                0      Gm11333                 NaN
# 1                                0     Vmn1r211                 NaN
# 2                             2856          NaN  Hist1h3f,Hist1h2bh
# 3                                0          NaN                 NaN
# 4                             2856          NaN  Hist1h3f,Hist1h2bh
#
#    R1-Down-Genes  R2-Down-Genes  \
# 0            NaN            NaN
# 1        Gm11320            NaN
# 2            NaN            NaN
# 3             U3            NaN
# 4            NaN            NaN
#
#                                     R1-Overlap-Genes  \
# 0                        4930557F10Rik,4930586N03Rik
# 1                           Gm11319,SNORA17,Vmn1r212
# 2               Abt1,C230035I16Rik,AL714025.1,Btn1a1
# 3  Prss16,Gm11290,Gm11291,Gm11292,Hist1h2ah,Hist1...
# 4                     Gm11280,Zfp184,Gm11281,Gm11282
#
#                                     R2-Overlap-Genes          R1-Overlap-TADs  \
# 0                      4930586N03Rik,Zfp322a,Gm11334  chr13:22200000-23720000
# 1  Gm11331,Gm11332,4930557F10Rik,4933404K08Rik,Gm...  chr13:22200000-23720000
# 2  Hist1h4f,Hist1h1d,Hist1h3e,Hist1h2ae,Hist1h2bg...  chr13:22200000-23720000
# 3  Gm11331,Gm11332,4930557F10Rik,4933404K08Rik,Gm...  chr13:21920000-22120000
# 4  Hist1h4f,Hist1h1d,Hist1h3e,Hist1h2ae,Hist1h2bg...  chr13:21920000-22120000
#
#            R2-Overlap-TADs
# 0  chr13:22200000-23720000
# 1  chr13:22200000-23720000
# 2  chr13:22200000-23720000
# 3  chr13:22200000-23720000
# 4  chr13:22200000-23720000
#
# [5 rows x 130 columns]

# %%
selected_nodes = df.name.tolist() + df.variable.tolist()
selected_nodes = list(set(selected_nodes))

# %%
G=nx.from_pandas_edgelist(df, 'name', 'variable', edge_attr=['value','distance'])

# %%
G['chr13:23880000-23910000']['chr13:24240000-24270000']
# Out:
# {'distance': 12.0, 'value': 0.942272}

# %%
nodes = pd.read_csv("mESC_HindIII_loci_features.csv",index_col=0)

# %%
nodes.head()
# Out:
#                       ZNF384.ES-E14.ENCFF960DFA  H3K4me1.ES-E14.ENCFF440FYE  \
# name
# chr1:1491226-1531226                          0                           0
# chr1:3022145-3062145                          0                           0
# chr1:3055439-3095439                          0                           0
# chr1:3090241-3130241                          0                           0
# chr1:3145070-3185070                          0                           0
#
#                       H3K36me3.E14TG2a.4.ENCFF759WKW  chen2008-NMYC.fimo  \
# name
# chr1:1491226-1531226                               0                   0
# chr1:3022145-3062145                               0                  27
# chr1:3055439-3095439                               0                   9
# chr1:3090241-3130241                               0                   0
# chr1:3145070-3185070                               0                  18
#
#                       DNase.ZHBTc4-mESC.ENCFF485JVJ  \
# name
# chr1:1491226-1531226                              0
# chr1:3022145-3062145                              0
# chr1:3055439-3095439                              0
# chr1:3090241-3130241                              0
# chr1:3145070-3185070                              0
#
#                       H3K4me3.ES-Bruce4.ENCFF247GVM  DNase.WW6.ENCFF038FMN  \
# name
# chr1:1491226-1531226                              0                      0
# chr1:3022145-3062145                              0                    450
# chr1:3055439-3095439                              0                      0
# chr1:3090241-3130241                              0                      0
# chr1:3145070-3185070                              0                      0
#
#                       chen2008-SMAD1.fimo  ZC3H11A.ES-E14.ENCFF024QSW  \
# name
# chr1:1491226-1531226                    0                           0
# chr1:3022145-3062145                  390                           0
# chr1:3055439-3095439                  585                           0
# chr1:3090241-3130241                  360                           0
# chr1:3145070-3185070                  410                           0
#
#                       H3K4me1.ES-Bruce4.ENCFF333IJH          ...           \
# name                                                         ...
# chr1:1491226-1531226                              0          ...
# chr1:3022145-3062145                              0          ...
# chr1:3055439-3095439                              0          ...
# chr1:3090241-3130241                              0          ...
# chr1:3145070-3185070                              0          ...
#
#                       DNase.WW6.ENCFF227YIF  CHD2.ES-E14.ENCFF466DTV  \
# name
# chr1:1491226-1531226                      0                        0
# chr1:3022145-3062145                    300                        0
# chr1:3055439-3095439                      0                        0
# chr1:3090241-3130241                      0                        0
# chr1:3145070-3185070                    150                        0
#
#                       H3K4me3.E14TG2a.4.ENCFF406BED  DNase.ES-E14.ENCFF809UQX  \
# name
# chr1:1491226-1531226                              0                         0
# chr1:3022145-3062145                              0                       300
# chr1:3055439-3095439                              0                         0
# chr1:3090241-3130241                              0                       150
# chr1:3145070-3185070                              0                         0
#
#                       DNase.WW6.ENCFF448HUO  POLR2A.ES-Bruce4.ENCFF860MNF  \
# name
# chr1:1491226-1531226                      0                             0
# chr1:3022145-3062145                    450                             0
# chr1:3055439-3095439                      0                             0
# chr1:3090241-3130241                      0                             0
# chr1:3145070-3185070                      0                             0
#
#                       Up-Genes  Down-Genes  Overlap-Genes  \
# name
# chr1:1491226-1531226       NaN         NaN            NaN
# chr1:3022145-3062145       NaN         NaN        Gm16088
# chr1:3055439-3095439       NaN         NaN             U6
# chr1:3090241-3130241       NaN         NaN             U6
# chr1:3145070-3185070       NaN         NaN            NaN
#
#                               Overlap-TADs
# name
# chr1:1491226-1531226                   NaN
# chr1:3022145-3062145  chr1:3000000-4360000
# chr1:3055439-3095439  chr1:3000000-4360000
# chr1:3090241-3130241  chr1:3000000-4360000
# chr1:3145070-3185070  chr1:3000000-4360000
#
# [5 rows x 63 columns]

# %%
nodes = nodes.fillna("")

# %%
pd.Series(nodes[c], index=["chr13:23280000-23310000"])
# Out:
# chr13:23280000-23310000    chr13:22200000-23720000
# Name: Overlap-TADs, dtype: object

# %%
for c in nodes.columns:
    nx.set_node_attributes(G, pd.Series(nodes[c], index=selected_nodes).to_dict(), c.replace(".","").replace("-",""))

# %%
G.node['chr13:23880000-23910000']
# Out:
# {'CHD2ESE14ENCFF466DTV': 0,
#  'CTCFE14TG2a4ENCFF969YUQ': 165,
#  'CTCFESBruce4ENCFF926DQD': 200,
#  'DNaseESE14ENCFF167GZG': 150,
#  'DNaseESE14ENCFF797POV': 0,
#  'DNaseESE14ENCFF809UQX': 150,
#  'DNaseESE14ENCFF911LAE': 0,
#  'DNaseWW6ENCFF038FMN': 0,
#  'DNaseWW6ENCFF227YIF': 0,
#  'DNaseWW6ENCFF448HUO': 0,
#  'DNaseWW6ENCFF594LCV': 300,
#  'DNaseWW6ENCFF651VVB': 150,
#  'DNaseWW6ENCFF673WPS': 0,
#  'DNaseWW6ENCFF971CGW': 0,
#  'DNaseWW6ENCFF994GNO': 0,
#  'DNaseZHBTc4mESCENCFF082FXK': 300,
#  'DNaseZHBTc4mESCENCFF096WRW': 0,
#  'DNaseZHBTc4mESCENCFF111WVB': 0,
#  'DNaseZHBTc4mESCENCFF485JVJ': 300,
#  'DownGenes': '',
#  'EP300ESBruce4ENCFF350GCX': 0,
#  'H3K27acESBruce4ENCFF360VIS': 0,
#  'H3K27acESE14ENCFF194TQD': 0,
#  'H3K27me3E14TG2a4ENCFF988MSF': 1527,
#  'H3K27me3ESBruce4ENCFF558YNC': 0,
#  'H3K36me3E14TG2a4ENCFF759WKW': 0,
#  'H3K36me3ESBruce4ENCFF299BTW': 0,
#  'H3K36me3ESE14ENCFF556TVG': 0,
#  'H3K4me1E14TG2a4ENCFF763GNF': 0,
#  'H3K4me1ESBruce4ENCFF333IJH': 0,
#  'H3K4me1ESE14ENCFF067VMS': 0,
#  'H3K4me1ESE14ENCFF440FYE': 0,
#  'H3K4me3E14TG2a4ENCFF406BED': 0,
#  'H3K4me3ESBruce4ENCFF247GVM': 0,
#  'H3K4me3ESE14ENCFF012AZO': 0,
#  'H3K4me3ESE14ENCFF680CYO': 0,
#  'H3K9acESBruce4ENCFF290XDT': 0,
#  'H3K9acESE14ENCFF487JDK': 0,
#  'H3K9me3E14TG2a4ENCFF180LQA': 0,
#  'H3K9me3ESBruce4ENCFF834MWI': 466,
#  'H3K9me3ESE14ENCFF090UKL': 0,
#  'HCFC1ESE14ENCFF030DBG': 0,
#  'MAFKESE14ENCFF535CTU': 0,
#  'NANOGE14TG2a4ENCFF557KRT': 0,
#  'OverlapGenes': 'Trim38,Gm11337,Slc17a2',
#  'OverlapTADs': 'chr13:23840000-25040000',
#  'POLR2AESBruce4ENCFF860MNF': 0,
#  'POU5F1E14TG2a4ENCFF499ROE': 0,
#  'UpGenes': '',
#  'ZC3H11AESE14ENCFF024QSW': 256,
#  'ZNF384ESE14ENCFF960DFA': 350,
#  'chen2008CMYCfimo': 18,
#  'chen2008CTCFfimo': 270,
#  'chen2008ESRRBfimo': 165,
#  'chen2008KLF4fimo': 81,
#  'chen2008NANOGfimo': 270,
#  'chen2008NMYCfimo': 18,
#  'chen2008OCT4fimo': 112,
#  'chen2008SMAD1fimo': 315,
#  'chen2008SOX2fimo': 182,
#  'chen2008STAT3fimo': 92,
#  'chen2008TCFCP2I1fimo': 91,
#  'chen2008ZFXfimo': 22}

# %%
nx.write_gml(G, 'Mouse_Hist1.gml')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
nx.draw(G)
