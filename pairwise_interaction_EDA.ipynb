# %%
import pandas as pd

# %%
df = pd.read_csv("SLICE_08_pos.csv",index_col = 0)

# %%
df.head()
# Out:
#                       CHD2.ES-E14.ENCFF466DTV  H3K36me3.E14TG2a.4.ENCFF759WKW  \
# chr1:4140000-4170000                        0                               0
# chr1:4320000-4350000                        0                               0
# chr1:4350000-4380000                        0                               0
# chr1:4380000-4410000                        0                               0
# chr1:5820000-5850000                        0                               0
#
#                       H3K9me3.ES-E14.ENCFF090UKL  DNase.WW6.ENCFF971CGW  \
# chr1:4140000-4170000                           0                      1
# chr1:4320000-4350000                           0                      1
# chr1:4350000-4380000                           0                      0
# chr1:4380000-4410000                           0                      1
# chr1:5820000-5850000                           0                      0
#
#                       H3K4me1.ES-Bruce4.ENCFF333IJH  \
# ...

# %%
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1)
sns.clustermap(df.corr(),cmap="RdBu_r",figsize=(15,15))

# %%
sns.clustermap(df.transpose(),standard_scale=0,method="ward",figsize=(15,15))

# %%
sns.color_palette("hls", 8)
# Out:
# [(0.86, 0.37119999999999997, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.56880000000000008, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.50120000000000009),
#  (0.33999999999999997, 0.82879999999999987, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.63119999999999976, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.69879999999999964)]
