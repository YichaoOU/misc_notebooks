# %%
import pandas as pd
correct_order = ["AT1G10620","AT1G49270","AT4G34440","AT3G18810","AT2G24450","AT1G23540","AT4G33970","AT1G54215","AT2G18470","AT1G24520","AT3G01700","AT5G14380","AT3G57690"]
data = pd.read_csv("liyc_pollen_HRGP_base2.csv",index_col=0)

# %%
import pandas as pd
correct_order = ["AT1G10620","AT1G49270","AT4G34440","AT3G18810","AT2G24450","AT1G23540","AT4G33970","AT1G54215","AT2G18470","AT1G24520","AT3G01700","AT5G14380","AT3G57690"]
correct_order = map(lambda x:x[0]+x.lower()[1:],correct_order)
data2 = pd.read_csv("motif_location_table.csv",index_col=0,dtype=str)
data2.index
data2 = data2.reindex(correct_order)
data2
data2.to_csv("motif_location_table.correct_order.csv")

# %%
data = data.reindex(correct_order)

# %%
data.to_csv("liyc_pollen_HRGP_base2.correct_order.csv")

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
data.plot(figsize=(10,20))
