# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Hist1.Dprime.embeddings.csv",header = None, index_col=0)

# %%
df.describe().to_csv("test.csv")

# %%
df.head()
# Out:
#                         1         2         3         4         5         6   \
# 0
# 0  chr13:22200000-22230000 -0.078697  0.271532 -0.042073  0.058878 -0.018328
# 1  chr13:22860000-22890000 -0.209566  0.255979 -0.312300  0.080569 -0.341595
# 2  chr13:23700000-23730000  0.062319  0.454758 -0.102039 -0.180765 -0.434595
# 3  chr13:23850000-23880000 -0.042817 -0.022392 -0.415476  0.351237 -0.110250
# 4  chr13:22710000-22740000  0.106987  0.258482 -0.115530 -0.346526 -0.185661
#
#          7         8         9         10    ...           56        57  \
# 0                                            ...
# 0 -0.067419  0.288789  0.021907 -0.073923    ...    -0.221123  0.600538
# 1  0.130609  0.483752  0.315475  0.570088    ...    -0.045826  0.077866
# 2 -0.088161 -0.085991 -0.065123  0.269780    ...     0.071686  0.345825
# 3  0.470053  0.078260 -0.254786  0.333100    ...     0.121992 -0.161906
# 4  0.181941  0.084525 -0.029503  0.174137    ...     0.057426  0.093457
#
# ...

# %%
df = df.set_index(1)

# %%
from sklearn import manifold

# %%
my_scaler = manifold.MDS(n_jobs=-1)
MDS_data = my_scaler.fit_transform(df)

# %%
MDS_data
# Out:
# array([[-1.156323  ,  0.52965801],
#        [ 0.17696305,  1.26405259],
#        [ 1.04675141, -0.76078438],
#        ...,
#        [ 1.8738466 ,  0.86862864],
#        [ 0.62625682,  1.5606034 ],
#        [ 1.75455762,  0.24134141]])

# %%
import matplotlib.pyplot as plt
plt.scatter(MDS_data[:, 0], MDS_data[:, 1], alpha=0.2)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df)
X_pca = pca.transform(df)

# %%
X_pca
# Out:
# array([[ 1.39614763, -0.26712705],
#        [-0.22633399,  0.40937604],
#        [-0.57923994, -0.31821487],
#        ...,
#        [-0.82253038, -1.06284633],
#        [-0.39231271,  0.06763111],
#        [-0.69129516, -0.6291147 ]])

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.2)

# %%
my_scaler = manifold.TSNE()
TSNE_data = my_scaler.fit_transform(df)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], alpha=0.2)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=4,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=3,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=6,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=7,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=10,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=3,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=14,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
kmeans = KMeans(n_clusters=13,n_jobs=-1)
kmeans.fit(TSNE_data)
y_kmeans = kmeans.predict(TSNE_data)
plt.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
fig, ax = plt.subplots()
ax.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis',alpha=0.2)

centers = kmeans.cluster_centers_
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
for i in range(len(centers)):
    ax.annotate(str(i), (centers[i,0], centers[i,1]),color='g',size=20)

# %%
fig, ax = plt.subplots()
ax.scatter(TSNE_data[:, 0], TSNE_data[:, 1], c=y_kmeans, s=50, cmap='viridis',alpha=0.2)

centers = kmeans.cluster_centers_
ax.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
for i in range(len(centers)):
    ax.annotate(str(i), (centers[i,0], centers[i,1]),color='g',size=20)

# %%
new_df = pd.DataFrame(TSNE_data)
new_df.columns = ['T1','T2']
new_df['label'] = list(kmeans.labels_)
new_df.index = df.index
new_df['start'] = pd.Series(df.index).apply(lambda x:x.split("-")[0].split(":")[-1]).astype(int).tolist()
new_df[(new_df['start'] < 24100000) & (new_df['start'] > 21700000)].boxplot(column=['start'], by=['label'])

# %%
sns.lmplot(x="start",y="label",data=new_df.sort_values('start'))

# %%
new_df = pd.DataFrame(TSNE_data)
new_df.columns = ['T1','T2']
new_df['label'] = list(kmeans.labels_)

# %%
new_df.head()
# Out:
#           T1         T2  label
# 0  35.177322  -1.302723      5
# 1  10.048419 -24.898544      4
# 2  -1.666334  20.477026      0
# 3  -5.131012  38.345757      0
# 4  11.264097  -7.486571      1

# %%
new_df.index = df.index

# %%
new_df.head()
# Out:
#                                 T1         T2  label
# 1
# chr13:22200000-22230000  35.177322  -1.302723      5
# chr13:22860000-22890000  10.048419 -24.898544      4
# chr13:23700000-23730000  -1.666334  20.477026      0
# chr13:23850000-23880000  -5.131012  38.345757      0
# chr13:22710000-22740000  11.264097  -7.486571      1

# %%
new_df['start'] = pd.Series(df.index).apply(lambda x:x.split("-")[0].split(":")[-1]).astype(int).tolist()

# %%
new_df.head()
# Out:
#                                 T1         T2  label     start
# 1
# chr13:22200000-22230000  35.177322  -1.302723      5  22200000
# chr13:22860000-22890000  10.048419 -24.898544      4  22860000
# chr13:23700000-23730000  -1.666334  20.477026      0  23700000
# chr13:23850000-23880000  -5.131012  38.345757      0  23850000
# chr13:22710000-22740000  11.264097  -7.486571      1  22710000

# %%
new_df[(new_df['start'] < 24100000) & (new_df['start'] > 21700000)].boxplot(column=['start'], by=['label'])

# %%
temp = new_df[(new_df['start'] < 24100000) & (new_df['start'] > 21700000)]

# %%
temp_sort = temp.sort_values('start')

# %%
sns.lmplot(x="start",y="label",data=new_df.sort_values('start'))

# %%
temp[temp['label'] == 9]
# Out:
#                                T1         T2  label     start
# 1
# chr13:22980000-23010000 -4.733938 -36.368904      9  22980000

# %%
sns.lmplot(x="start",y="label",data=new_df.sort_values('start'))

# %%
temp.loc["chr13:23010000-23040000"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# E:\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [chr13:23010000-23040000] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-1f1971cbb40b> in <module>()
# ----> 1 temp.loc["chr13:23010000-23040000"]
#
# ...

# %%
new_df[(new_df['start'] < 21970000) & (new_df['start'] > 21770000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:21900000-21930000 -36.847946  -4.214420      7  21900000
# chr13:21960000-21990000   9.159446   3.270900      8  21960000
# chr13:21840000-21870000 -32.552410 -12.271324      7  21840000
# chr13:21810000-21840000  11.655547  21.376127      8  21810000
# chr13:21780000-21810000   6.658249  14.380685      8  21780000
# chr13:21930000-21960000 -10.614385   9.097397      6  21930000
# chr13:21870000-21900000  11.916286  15.096026      8  21870000

# %%
new_df[(new_df['start'] < 21970000) & (new_df['start'] > 21770000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:21900000-21930000 -36.847946  -4.214420      1  21900000
# chr13:21960000-21990000   9.159446   3.270900      2  21960000
# chr13:21840000-21870000 -32.552410 -12.271324      1  21840000
# chr13:21810000-21840000  11.655547  21.376127      1  21810000
# chr13:21780000-21810000   6.658249  14.380685      1  21780000
# chr13:21930000-21960000 -10.614385   9.097397      1  21930000
# chr13:21870000-21900000  11.916286  15.096026      2  21870000

# %%
new_df[(new_df['start'] < 22180000) & (new_df['start'] > 22080000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:22110000-22140000   3.662645  -1.983631      1  22110000
# chr13:22170000-22200000  -4.929560 -12.466714     10  22170000
# chr13:22140000-22170000 -14.266776  -6.190395      2  22140000

# %%
new_df[(new_df['start'] < 22180000) & (new_df['start'] > 22080000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:22110000-22140000   3.662645  -1.983631      1  22110000
# chr13:22170000-22200000  -4.929560 -12.466714      0  22170000
# chr13:22140000-22170000 -14.266776  -6.190395      1  22140000

# %%
new_df[(new_df['start'] < 23700000) & (new_df['start'] > 23600000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:23640000-23670000 -25.213408  14.607201     11  23640000
# chr13:23670000-23700000 -24.884224  14.176487     11  23670000
# chr13:23610000-23640000 -20.664413   3.519884      6  23610000

# %%
new_df[(new_df['start'] < 23880000) & (new_df['start'] > 23750000)]
# Out:
#                                 T1         T2  label     start
# 1
# chr13:23850000-23880000  -5.131012  38.345757      0  23850000
# chr13:23760000-23790000  -8.315778  22.823870      0  23760000
# chr13:23820000-23850000 -36.264454   4.232944     11  23820000
# chr13:23790000-23820000 -14.229396  23.579527     12  23790000

# %%
new_df[(new_df['start'] < 24050000) & (new_df['start'] > 24000000)]
# Out:
#                                T1         T2  label     start
# 1
# chr13:24030000-24060000 -19.73241  32.797939     12  24030000

# %%
new_df[(new_df['start'] < 23600000) & (new_df['start'] > 22180000)].sort_values("label")
# Out:
#                                 T1         T2  label     start
# 1
# chr13:22770000-22800000   2.210534 -13.390079      1  22770000
# chr13:22710000-22740000  11.264097  -7.486571      1  22710000
# chr13:22800000-22830000   5.224202 -14.896554      1  22800000
# chr13:22890000-22920000 -15.418550  -6.810560      2  22890000
# chr13:23280000-23310000 -14.981885  -5.678419      2  23280000
# chr13:23460000-23490000 -16.767122  -5.028232      2  23460000
# chr13:22230000-22260000 -17.471624  -5.224030      2  22230000
# chr13:23190000-23220000 -19.414854  -6.333429      2  23190000
# chr13:22410000-22440000  -6.517089  -8.925038      2  22410000
# chr13:23070000-23100000 -17.482607  -5.116864      2  23070000
# chr13:22260000-22290000 -11.148252  -4.225471      2  22260000
# chr13:23490000-23520000 -13.573583  -0.632878      2  23490000
# chr13:23430000-23460000 -21.575998   1.498186      2  23430000
# chr13:23250000-23280000 -14.572891  -6.155128      2  23250000
# ...

# %%
pd.Series(df.index).apply(lambda x:x.split("-")[0].split(":")[-1])
# Out:
# 0        22200000
# 1        22860000
# 2        23700000
# 3        23850000
# 4        22710000
# 5        23760000
# 6        21900000
# 7        23880000
# 8        23550000
# 9        23400000
# 10       24090000
# 11       23040000
# 12       22020000
# 13       23640000
# 14       23670000
# 15       23820000
# 16       24060000
# 17       21960000
# 18       21840000
# 19       23310000
# 20       21990000
# 21       23730000
# 22       24000000
# 23       22050000
# 24       23340000
# 25       22740000
# 26       22320000
# 27       21810000
# 28       22530000
# 29       22650000
#           ...
# 1462     43680000
# 1463     48840000
# 1464     15690000
# 1465     41940000
# 1466     60900000
# 1467     57750000
# 1468     66690000
# 1469     17700000
# 1470     72270000
# 1471     53100000
# 1472     38100000
# 1473     41070000
# 1474     51630000
# 1475     31260000
# 1476     55950000
# 1477     69000000
# 1478     80460000
# 1479     33300000
# 1480     56250000
# ...

# %%
centers[0,0]
# Out:
# -5.370909
